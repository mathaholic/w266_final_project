# %% [markdown]
# ## W266 Final Project

# %%
import numpy as np
import pandas as pd
import re
import glob #this makes a list of all the files in a directory
from pandasql import sqldf
pysqldf = lambda q: sqldf(q, globals())
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.utils import shuffle
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import BernoulliNB
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.feature_extraction.text import *

# %%
files_list = glob.glob("./data/imsdb_scenes_dialogs_nov_2015/dialogs/*/*_dialog.txt")

file_array = np.array(files_list)
files = pd.DataFrame(file_array.reshape(-1,1), columns=["FilePath"])

title_list = []
genre_list = []
for i in files.index:
    genretitle = files['FilePath'][i][45:] #get rid of all the ./data/imsdb...
    a, b = genretitle.split("/")
    genre_list.append(a)
    title_list.append(b[:-11]) #take off '_dialog.txt' from the file name
    
    
files['Genre']=genre_list
files['Title']=title_list

files.head()
# Out:
#                                             FilePath   Genre             Title
# 0  ./data/imsdb_scenes_dialogs_nov_2015/dialogs/H...  Horror     redridinghood
# 1  ./data/imsdb_scenes_dialogs_nov_2015/dialogs/H...  Horror     aprilfoolsday
# 2  ./data/imsdb_scenes_dialogs_nov_2015/dialogs/H...  Horror         hollowman
# 3  ./data/imsdb_scenes_dialogs_nov_2015/dialogs/H...  Horror  queenofthedamned
# 4  ./data/imsdb_scenes_dialogs_nov_2015/dialogs/H...  Horror         grudgethe

# %%
movie1 = pd.read_fwf('./data/imsdb_scenes_dialogs_nov_2015/dialogs/Adventure/avatar_dialog.txt',
                    header=None, names=["RawLine"],encoding='utf')
movie2 = pd.read_fwf('./data/imsdb_scenes_dialogs_nov_2015/dialogs/Adventure/1492conquestofparadise_dialog.txt',
                    header=None, names=["RawLine"],encoding='utf')
movie1.head(n=10)
### suggestion: always read in movies as UTF-8 so we don't have weird “&amp;amp;”  instead of &
# Out:
#                                    RawLine
# 0                                   AVATAR
# 1                               Written by
# 2                            James Cameron
# 3                             VOICE (V.O.)
# 4         When I was lying there in the VA
# 5  hospital, with a big hole blown through
# 6  the middle of my life, I started having
# 7                  these dreams of flying.
# 8                             VOICE (V.O.)
# 9  Sooner or later though, you always have

# %%
def is_name(string):
    string1 = re.sub(r'\W+', '', re.sub('(V.O.)|CUT TO:','',string))
    n = re.match('[A-Z][A-Z]+', string1)
    if n: return True
    else: return False

def is_speech(string):
    if not is_name(string):
        return True
    else: return False

def is_cutto(string):
    n = re.match('CUT TO', string)
    #print n
    if n: return True
    else: return False
    

def parse_movie(movie, genre, title):   
#   Args:
#     movie is a pandas dataframe of the raw movie script input
#     genre is the movie genre from the folder it's read in from
#     title is the title (file name prior to _dialog.txt)
#   Output:
#     a dataframe of the form below
    curr_char = None
    line = 0
    title_column=[]
    genre_column=[]
    char_column=[]
    speech_column=[]
    line_column=[]
    pkey_column=[]
    for i in movie.index:
        title_column.append(title) 
        genre_column.append(genre) 
        current = str(movie['RawLine'][i])
        #current = str(current)
        #print current
        if current.lower() == 'nan':
            pass
            #print 'stop'

        elif is_cutto(current):
            char_column.append("")
            line_column.append(line)
            speech_column.append("")
            pkey_column.append("")

        elif is_name(current):

            #starting a new character. hold onto this name for the next lines
            #until you see another new character name
            #also try to remove things that are irrelevant to the name 
            ### nikki edit: add in str.strip() in case voice over left whitespaces
            curr_char = re.sub('\(V.O.\)|V.O.|\(O.S.\)|O.S.|\(CONT\'D\)|CONT\'D','',current).strip()
            char_column.append(curr_char)
            pkey_column.append((curr_char+'-'+title).lower().replace(' ', '_'))

            line += 1
            line_column.append(line)
            speech_column.append("")

        elif is_speech(current):

            char_column.append(curr_char)
            line_column.append(line)
            speech_column.append(current)
            if curr_char is not None:
                pkey_column.append((curr_char+'-'+title).lower())
                

    movie['Title']=title_column
    movie['Genre']=genre_column
    movie['Char']=char_column
    movie['LineID']=line_column
    movie['Speech']=speech_column
    movie['pkey']=pkey_column

    return movie



parse_movie(movie1, 'Adventure', 'avatar')
movie1.head(n=10)
    
#Intermediate dataframe should look something like this:

#RawLine                                  Title     Genre      Char   LineID     Speech

#JAKE (V.O.)                              Avatar    Adventure  JAKE   1 
#They can fix a spinal, if you've got the Avatar    Adventure  JAKE   1          They can fix... 
#money. But not on vet benefits, not in   Avatar    Adventure  JAKE   1          money. But not...


#And then we eventually aggregate by LineID to:

#Title   Genre      Char  Speech
#Avatar  Adventure  JAKE  They can fix a spinal, if you've got the money. But not on vet...
# Out:
#                                    RawLine   Title      Genre    Char  LineID  \
# 0                                   AVATAR  avatar  Adventure  AVATAR       1
# 1                               Written by  avatar  Adventure  AVATAR       1
# 2                            James Cameron  avatar  Adventure  AVATAR       1
# 3                             VOICE (V.O.)  avatar  Adventure   VOICE       2
# 4         When I was lying there in the VA  avatar  Adventure   VOICE       2
# 5  hospital, with a big hole blown through  avatar  Adventure   VOICE       2
# 6  the middle of my life, I started having  avatar  Adventure   VOICE       2
# 7                  these dreams of flying.  avatar  Adventure   VOICE       2
# 8                             VOICE (V.O.)  avatar  Adventure   VOICE       3
# 9  Sooner or later though, you always have  avatar  Adventure   VOICE       3
#
#                                     Speech           pkey
# ...

# %%
movie1['Char'].value_counts()
# Out:
# JAKE                                       757
# GRACE                                      434
# QUARITCH                                   253
# NEYTIRI                                    186
# SELFRIDGE                                  137
# NORM                                       123
# (SUBTITLED)                                119
# TRUDY                                       93
#                                             87
# MAX                                         69
# MO'AT                                       63
# TSU'TEY                                     55
# WAINFLEET                                   33
# EYTUKAN                                     18
# PILOT                                       17
# MED TECH                                    13
# CREW CHIEF                                  13
# TROOPER                                     11
# JAKE (RECORDED)                             10
# (QUIETLY)                                    8
# ...

# %%
### keep only characters with at least 20 lines per movie

def top_chars(df, threshold = 20):
    threshold = threshold
    char_list = pd.DataFrame(df["Char"].value_counts())
    to_remove = char_list[char_list['Char'] <= threshold].index
    cl1 = char_list.drop(to_remove)
    cl1['line_count'] = cl1['Char']
    cl1['Char'] = cl1.index
    query = 'SELECT d.*, c.line_count FROM df d INNER JOIN cl1 c on d.Char = c.Char'
    enriched_df = sqldf(query, locals())
    enriched_df = enriched_df[enriched_df['Char'] != '']
    return enriched_df

def pipeline(df,threshold=20):
    ### before top chars, we can add something about a proper title finder
    tc = top_chars(df, threshold)
    
    ### add something about the gender id
    ### add something about vocab enrichment
    ### output should be called final_df
    final_df = tc
    return tc
    

enriched_movie1 = pipeline(movie1)

# %%
enriched_movie1.head()
# Out:
#                                     RawLine   Title      Genre  Char  LineID  \
# 1                               JAKE (V.O.)  avatar  Adventure  JAKE       4
# 2  They can fix a spinal, if you've got the  avatar  Adventure  JAKE       4
# 3    money. But not on vet benefits, not in  avatar  Adventure  JAKE       4
# 4                             this economy.  avatar  Adventure  JAKE       4
# 5                               JAKE (V.O.)  avatar  Adventure  JAKE       6
#
#                                      Speech         pkey  line_count
# 1                                            jake-avatar         757
# 2  They can fix a spinal, if you've got the  jake-avatar         757
# 3    money. But not on vet benefits, not in  jake-avatar         757
# 4                             this economy.  jake-avatar         757
# 5                                            jake-avatar         757

# %%
enriched_movie1['Char'].value_counts()
# Out:
# JAKE           757
# GRACE          434
# QUARITCH       253
# NEYTIRI        186
# SELFRIDGE      137
# NORM           123
# (SUBTITLED)    119
# TRUDY           93
# MAX             69
# MO'AT           63
# TSU'TEY         55
# WAINFLEET       33
# Name: Char, dtype: int64

# %%
not_working=[]
char_list_to_label=[]

for i in files_list:
    title = i.split('/')[5].split('_')[0]
    genre = i.split('/')[4]
    if genre=='Western':
        print i
        #print genre
        title = title.strip()
        genre = genre.strip()
        movie = pd.read_fwf("%s" % i,header=None, names=["RawLine"],encoding='utf')
        #print movie
        try:
            parsed = parse_movie(movie, genre, title)
            #print parsed.head()
            final_df = pipeline(movie)
            char_list = final_df.drop_duplicates(subset='Char',keep='last')[['Char','Genre','Title','line_count']]
            char_list_to_label.append(char_list)
        except:
            not_working.append((genre,title))
        #print final_df.head()
        print "processing next movie"
chars= pd.concat(char_list_to_label)
#chars.to_csv('OutputWesternCharacters.csv', index=False)
print not_working
chars.head()
# Out:
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Western/djangounchained_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Western/danceswithwolves_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Western/bookofelithe_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Western/tombstone_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Western/mariachiel_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Western/baddayatblackrock_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Western/stationwest_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Western/wildwildwest_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Western/truegrit_dialog.txt
# processing next movie
# ...

# %%
gender_labels = pd.read_csv('more_random_sampling.csv',na_values=["NA","N"])
gender_labels.head(n=40)

gender_labels = gender_labels.dropna(subset=['gender'])
gender_labels['gender'].value_counts()
# Out:
# M    1116
# F     599
# Name: gender, dtype: int64

# %%
gender_labels2 = pd.read_csv('AllRemaining.csv',na_values=["NA",","," ","na"])
gender_labels2.head(n=40)

gender_labels2 = gender_labels2.dropna(subset=['gender'])
gender_labels2['gender'].value_counts()

gender_labels2['char']=gender_labels2['Char']
gender_labels2['genre']=gender_labels2['Genre']

gender_labels2 = gender_labels2.drop(['Char','Genre','Title'], axis=1)

gender_labels2.head()
# Out:
#    id gender  line_count                    pkey      char     genre
# 0   1      M          58   mickena-assignmentthe   MICKENA  Thriller
# 1   2      F         134     carla-assignmentthe     CARLA  Thriller
# 2   3      F          65  agnieska-assignmentthe  AGNIESKA  Thriller
# 3   4      M          37       koj-assignmentthe       KOJ  Thriller
# 4   5      M         366      amos-assignmentthe      AMOS  Thriller

# %%
gender_labels_all = pd.concat([gender_labels, gender_labels2])
gender_labels_all.head()
# Out:
#        char gender    genre  id line_count                      pkey  \
# 0     WILLY      M  Musical   1         58           willy-sisteract
# 1     ATHOS      M   Action   2        378    athos-manintheironmask
# 2  AUGUSTUS      M   Action   3        222  augustus-perfectcreature
# 4     JIMMY      M  Romance   5         43     jimmy-mulhollanddrive
# 5    DENNIS      M    Drama   6         42          dennis-backdraft
#
#               title
# 0         sisteract
# 1  manintheironmask
# 2   perfectcreature
# 4   mulhollanddrive
# 5         backdraft

# %%
gender_labels_all['gender'].value_counts()
# Out:
# M    5140
# F    2172
# Name: gender, dtype: int64

# %%
"""
This takes forever, don't need to run it again. We saved the pickle files (separately by genre)

all_movies_parsed = []
counter=0
curr_genre = None
for i in files_list:
    title = i.split('/')[5].split('_')[0]
    genre = i.split('/')[4]
    if curr_genre != genre:
        counter=0
        curr_genre = genre
    #print genre
    counter+=1
    print counter
    print i
    title = title.strip()
    genre = genre.strip()
    movie = pd.read_fwf("%s" % i,header=None, names=["RawLine"],encoding='utf')
    #print movie
    try:
        parsed = parse_movie(movie, genre, title)
        #print parsed.head()
        final_df = pipeline(movie)
        all_movies_parsed.append(final_df)
    except:
        pass
all_movies = pd.concat(all_movies_parsed)

print all_movies.head()
"""
# Out:
# 1
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Horror/redridinghood_dialog.txt
# 2
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Horror/aprilfoolsday_dialog.txt
# 3
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Horror/hollowman_dialog.txt
# 4
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Horror/queenofthedamned_dialog.txt
# 5
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Horror/grudgethe_dialog.txt
# 6
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Horror/birdsthe_dialog.txt
# 7
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Horror/gremlins2_dialog.txt
# 8
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Horror/jennifersbody_dialog.txt
# 9
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Horror/manhunter_dialog.txt
# 10
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Horror/mummythe_dialog.txt
# 11
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Horror/slither_dialog.txt
# 12
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Horror/psycho_dialog.txt
# 13
# ...

# %%
#all_movies.to_pickle("AllMoviesDF.p")  #too big for git

# %%
#with_gender.to_pickle("WithGenderDF.p") #already pickled, don't run again

# %%
#splitting up pickle files by genre so git will accept them

#all_movies_1 = all_movies[all_movies['Genre']=='Drama']
#all_movies_1 = all_movies_1[all_movies_1['LineID']>=500]
#all_movies_1.to_pickle("Drama2Movies.p")
#all_movies_1.count()
# Out:
# RawLine       336144
# Title         336144
# Genre         336144
# Char          336144
# LineID        336144
# Speech        336144
# pkey          336144
# line_count    336144
# dtype: int64

# %%
#loop for reading the pickled files back in 
pickles_list = glob.glob("./MoviePickles/*Movies.p")

print pickles_list
all_movies_pickled=[]
for pickle in pickles_list:
    all_movies_pickled.append(pd.read_pickle(pickle))

all_movies = pd.concat(all_movies_pickled)
all_movies.head()
# Out:
# ['./MoviePickles/SportMovies.p', './MoviePickles/ThrillerMovies.p', './MoviePickles/Drama1Movies.p', './MoviePickles/ShortMovies.p', './MoviePickles/BiographyMovies.p', './MoviePickles/ActionMovies.p', './MoviePickles/FamilyMovies.p', './MoviePickles/MusicalMovies.p', './MoviePickles/ComedyMovies.p', './MoviePickles/HorrorMovies.p', './MoviePickles/MusicMovies.p', './MoviePickles/FilmNoirMovies.p', './MoviePickles/WesternMovies.p', './MoviePickles/Drama2Movies.p', './MoviePickles/AnimationMovies.p', './MoviePickles/RomanceMovies.p', './MoviePickles/CrimeMovies.p', './MoviePickles/AdventureMovies.p', './MoviePickles/FantasyMovies.p', './MoviePickles/WarMovies.p', './MoviePickles/HistoryMovies.p', './MoviePickles/SciFiMovies.p', './MoviePickles/MysteryMovies.p']
#                                              RawLine           Title  Genre  \
# 0                                  BRANDON VOICEOVER  twoforthemoney  Sport
# ...

# %%
query = 'SELECT m.*, g.gender FROM all_movies m INNER JOIN gender_labels_all g on m.pkey = g.pkey'
with_gender = sqldf(query, locals())
with_gender.head()
with_gender = with_gender[with_gender['Char'] != '']
with_gender = with_gender[with_gender['Speech'] != '']
with_gender = with_gender.drop_duplicates(subset=['pkey','LineID','Speech'],keep='last')
with_gender = with_gender.groupby(['gender','Char','Title','Genre','pkey','LineID']).Speech.unique().reset_index()

# %%
chars = all_movies.drop_duplicates(subset=['Char','Title'],keep='last')[['Char','Genre','Title','line_count']]
chars.head()
# Out:
#           Char     Genre          Title  line_count
# 171    MICKENA  Thriller  assignmentthe          58
# 1533     CARLA  Thriller  assignmentthe         134
# 1836  AGNIESKA  Thriller  assignmentthe          65
# 2009       KOJ  Thriller  assignmentthe          37
# 2027      AMOS  Thriller  assignmentthe         366

# %%
query = 'SELECT m.*, g.gender FROM chars m LEFT JOIN gender_labels g on m.Char = g.Char and m.Title=g.Title'
remaining = sqldf(query, locals())

# %%
remaining = remaining[remaining['gender'] != "M"]
remaining = remaining[remaining['gender'] != "F"]
remaining.count()
remaining.to_csv('Remaining.csv')

# %%
with_gender.to_pickle("WithGenderFinal.p")

# %%
with_gender = pd.read_pickle("WithGenderFinal.p")

# %%
with_gender['gender'].value_counts()
# Out:
# M    201934
# F     84804
# Name: gender, dtype: int64

# %%
round(143817.0/(143817+73298)*100,1)
# Out:
# 66.2

# %%
#baseline accuracy from picking most common class
round(20700.0/(20700+11017)*100,1)
# Out:
# 65.3

# %%
line_column=[]
for i in with_gender.index:
        line_column.append(' '.join(with_gender['Speech'][i]))
with_gender['Line']=line_column

with_gender['linelength']=with_gender['Line'].str.len()
with_gender.head()
# Out:
#   gender  Char                     Title    Genre  \
# 0      F  A.D.  battleofshakerheightsthe  Romance
# 1      F  A.D.  battleofshakerheightsthe  Romance
# 2      F  A.D.  battleofshakerheightsthe  Romance
# 3      F  A.D.  battleofshakerheightsthe  Romance
# 4      F  A.D.  battleofshakerheightsthe  Romance
#
#                             pkey  LineID  \
# 0  a.d.-battleofshakerheightsthe     739
# 1  a.d.-battleofshakerheightsthe     741
# 2  a.d.-battleofshakerheightsthe     744
# 3  a.d.-battleofshakerheightsthe     746
# 4  a.d.-battleofshakerheightsthe     763
#
#                                               Speech  \
# 0  [Okay, everyone. We're going to start, positio...
# 1  [Great. We'd like to use it. Can you, drive it...
# 2  [Don't know. We've got enough people., It does...
# 3  [(yells), Okay people. Listen to my voice., Fr...
# 4       [Standby for rehearsal. Cue the, explosion.]
#
#                                                 Line  linelength
# ...

# %%
with_gender_dum = pd.get_dummies(with_gender['gender'])
with_gender = pd.concat([with_gender, with_gender_dum],axis=1).drop(['F','gender'],1)
with_gender.head()
# Out:
#    Char                     Title    Genre                           pkey  \
# 0  A.D.  battleofshakerheightsthe  Romance  a.d.-battleofshakerheightsthe
# 1  A.D.  battleofshakerheightsthe  Romance  a.d.-battleofshakerheightsthe
# 2  A.D.  battleofshakerheightsthe  Romance  a.d.-battleofshakerheightsthe
# 3  A.D.  battleofshakerheightsthe  Romance  a.d.-battleofshakerheightsthe
# 4  A.D.  battleofshakerheightsthe  Romance  a.d.-battleofshakerheightsthe
#
#    LineID                                             Speech  \
# 0     739  [Okay, everyone. We're going to start, positio...
# 1     741  [Great. We'd like to use it. Can you, drive it...
# 2     744  [Don't know. We've got enough people., It does...
# 3     746  [(yells), Okay people. Listen to my voice., Fr...
# 4     763       [Standby for rehearsal. Cue the, explosion.]
#
#                                                 Line  linelength  M
# 0  Okay, everyone. We're going to start positioni...         239  0
# ...

# %%
with_gender_shuffle = shuffle(with_gender, random_state = 5)


# Randomly split into training and dev with scikit-learn helper function
train, test = train_test_split(with_gender_shuffle, test_size=0.2, random_state=100)
dev, test = train_test_split(test, test_size=0.5, random_state=200)

print train.shape
print dev.shape
print test.shape
# Out:
# (229390, 9)
# (28674, 9)
# (28674, 9)

# %%
train_y, dev_y, test_y = train.M, dev.M, test.M
train_X = train.drop(['M','Speech','LineID'],1)
dev_X = dev.drop(['M','Speech','LineID'],1)
test_X = test.drop(['M','Speech','LineID'],1)
dev_X.head()
# Out:
#             Char         Title    Genre                pkey  \
# 151043      GARY     antitrust    Crime      gary-antitrust
# 62727      NADIA  birthdaygirl    Crime  nadia-birthdaygirl
# 203327     MARTY         marty  Romance         marty-marty
# 39225   JENNIFER       scream3  Mystery    jennifer-scream3
# 102806     BLOOM   producerthe   Comedy   bloom-producerthe
#
#                                                      Line  linelength
# 151043  The purpose of this company isn't to destroy o...         226
# 62727                I know you just want to punish me --          36
# 203327  I like you. I like you. I been telling you all...          67
# 39225                              Sidney, what happened?          22
# 102806               I never should have listened to you.          36

# %%
#baseline models

train_lines = train_X.Line.values
dev_lines = dev_X.Line.values

v = TfidfVectorizer()
v_train=v.fit_transform(train_lines)
vocab_train=v.vocabulary_

print "vocab size (all)", len(v.vocabulary_)

v_dev = v.transform(dev_lines)

print 'Logistic Regression on Line Lengths'
lg = LogisticRegression()
lg.fit(train_X.linelength.values.reshape(-1,1), train_y.values.reshape(-1,1))
print 'Weighted F1 Score:'
print metrics.f1_score(lg.predict(dev_X.linelength.values.reshape(-1,1)),dev_y.values.reshape(-1,1),average='weighted')
print 'Accuracy'
print metrics.accuracy_score(lg.predict(dev_X.linelength.values.reshape(-1,1)),dev_y.values.reshape(-1,1))
print confusion_matrix(dev_y.values.reshape(-1,1),lg.predict(dev_X.linelength.values.reshape(-1,1)))
print '-----------------------'

print 'Naive Bayes on Lines'
nb = BernoulliNB()
nb.fit(v_train, train_y.values.reshape(-1,1))
nb_pred = nb.predict(v_dev)
print 'Weighted F1 Score:'
print metrics.f1_score(nb_pred,dev_y.values.reshape(-1,1),average='weighted')
print 'Accuracy'
print metrics.accuracy_score(nb_pred,dev_y.values.reshape(-1,1))
print confusion_matrix(dev_y.values.reshape(-1,1),nb_pred)
#for i in range(100):
#    if dev_y.values.reshape(-1,1)[i]==nb_pred[i] and nb_pred[i]==0:
#        print "correct:", dev_lines[i], dev_y.values.reshape(-1,1)[i]
print '-----------------------'


print 'Logistic Regression on Lines'
lg = LogisticRegression()
lg.fit(v_train, train_y.values.reshape(-1,1))
print 'Weighted F1 Score:'
print metrics.f1_score(lg.predict(v_dev),dev_y.values.reshape(-1,1),average='weighted')
print 'Accuracy'
print metrics.accuracy_score(lg.predict(v_dev),dev_y.values.reshape(-1,1))
print confusion_matrix(dev_y.values.reshape(-1,1),lg.predict(v_dev))


features = list()
#words that are mostly male
max_weights = list(np.argpartition(lg.coef_[0],-15))[-15:]
for w in max_weights:
    features.append(w)
#words that are mostly female
min_weights = list(np.argpartition(lg.coef_[0],15))[:15]
for m in min_weights:
    features.append(m)

#Make a table with these features and weights
table={}
for f in features:
    weights=list()
    weights.append(round(lg.coef_[0][f],3))
    table[str(v.get_feature_names()[f])]=weights



#Print the table
print 'Word Weights (Negative = More Female, Positive = More Male)'

print "{:<15} {:<30}".format('Feature', 'Male')
for key in sorted(table, key=table.get):
    print "{:<15} {:<30}".format(key, table[key][0])



print '-----------------------'
# Out:
# vocab size (all) 49940
# Logistic Regression on Line Lengths
# /home/michelle_m_kim/anaconda2/lib/python2.7/site-packages/sklearn/utils/validation.py:526: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Weighted F1 Score:
# 0.827766648951
# Accuracy
# 0.706144939667
# [[    0  8426]
#  [    0 20248]]
# -----------------------
# Naive Bayes on Lines
# /home/michelle_m_kim/anaconda2/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# Weighted F1 Score:
# 0.746418459334
# Accuracy
# 0.705656692474
# [[ 1887  6539]
#  [ 1901 18347]]
# -----------------------
# Logistic Regression on Lines
# Weighted F1 Score:
# 0.790219113174
# Accuracy
# 0.716921252703
# [[ 1018  7408]
#  [  709 19539]]
# ...

# %%
#getting each character's vocab size
with_gender_vocabs = with_gender.groupby(['M','Char','Title','Genre','pkey']).Line.unique().reset_index() 
allline_column=[]
for i in with_gender_vocabs.index:
        allline_column.append(''.join(with_gender_vocabs['Line'][i]))
with_gender_vocabs['AllLines']=allline_column

with_gender_vocabs['Split']=with_gender_vocabs['AllLines'].str.split().apply(set)
with_gender_vocabs['VocabSize']=with_gender_vocabs['Split'].str.len()
with_gender_vocabs['WordCount']=with_gender_vocabs['AllLines'].str.len()
with_gender_vocabs['VocabRatio']=with_gender_vocabs['VocabSize']/with_gender_vocabs['WordCount']
with_gender_vocabs.head()
# Out:
#    M     Char                     Title    Genre  \
# 0  0     A.D.  battleofshakerheightsthe  Romance
# 1  0     ABBY         arsenicandoldlace    Crime
# 2  0  ABIGAIL              bladetrinity  Fantasy
# 3  0      ADA              coldmountain      War
# 4  0    ADELE                kalifornia    Crime
#
#                             pkey  \
# 0  a.d.-battleofshakerheightsthe
# 1         abby-arsenicandoldlace
# 2           abigail-bladetrinity
# 3               ada-coldmountain
# 4               adele-kalifornia
#
#                                                 Line  \
# 0  [Okay, everyone. We're going to start position...
# 1  [Reverend Harper, I do hope you don't disappro...
# 2  [Scream if this hurts, chica., I can., Forget ...
# 3  [Very much. It's beautiful country., Anyone? L...
# 4  [Early, you are so sweet., I feel kind of like...
#
#                                             AllLines  \
# 0  Okay, everyone. We're going to start positioni...
# ...

# %%
#use vocab size to represent complexity of speech

with_gender_vocabsz_shuffle = shuffle(with_gender_vocabs, random_state = 5)


train_vocabsz, test_vocabsz = train_test_split(with_gender_vocabsz_shuffle, test_size=0.2, random_state=100)
print train_vocabsz.shape
print test_vocabsz.shape

vs_train_y, vs_test_y = train_vocabsz.M, test_vocabsz.M
vs_train_X = train_vocabsz.drop(['M'],1)
vs_test_X = test_vocabsz.drop(['M'],1)
vs_test_X.head()


print 'Logistic Regression on Vocab Size'
lg_vs = LogisticRegression()
lg_vs.fit(vs_train_X.VocabSize.values.reshape(-1,1), vs_train_y.values.reshape(-1,1))
lg_vs_pred = lg_vs.predict(vs_test_X.VocabSize.values.reshape(-1,1))
print 'Weighted F1 Score:'
print metrics.f1_score(lg_vs_pred,vs_test_y.values.reshape(-1,1),average='weighted')
print 'Accuracy'
print metrics.accuracy_score(lg_vs_pred,vs_test_y.values.reshape(-1,1))
print 'Confusion Matrix'
print confusion_matrix(vs_test_y.values.reshape(-1,1),lg_vs_pred)
print '-----------------------'

print 'Logistic Regression on Ratio Vocab Size/Word Count'
lg_vsr = LogisticRegression()
lg_vsr.fit(vs_train_X.VocabRatio.values.reshape(-1,1), vs_train_y.values.reshape(-1,1))
print 'Weighted F1 Score:'
print metrics.f1_score(lg_vsr.predict(vs_test_X.VocabRatio.values.reshape(-1,1)),vs_test_y.values.reshape(-1,1),average='weighted')
print 'Accuracy'
print metrics.accuracy_score(lg_vsr.predict(vs_test_X.VocabRatio.values.reshape(-1,1)),vs_test_y.values.reshape(-1,1))
print '-----------------------'
# Out:
# (4391, 11)
# (1098, 11)
# Logistic Regression on Vocab Size
# Weighted F1 Score:
# 0.838095238095
# Accuracy
# 0.72131147541
# Confusion Matrix
# [[  0 306]
#  [  0 792]]
# -----------------------
# Logistic Regression on Ratio Vocab Size/Word Count
# Weighted F1 Score:
# 0.838095238095
# Accuracy
# 0.72131147541
# -----------------------

# %%
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline
sns.set(style='darkgrid', palette='muted', color_codes=True)
f, axes = plt.subplots(1,1, figsize=(12,8))
plt.title("Vocab Size Distributions by Gender and Movie Genre",fontsize=16)
sns.despine = True
sns.violinplot(data = with_gender_vocabs, x ="Genre", y="VocabSize", hue="M",split=True)
plt.xticks(rotation=45)
#plt.setp(axes, yticks=a)
plt.legend()
plt.plot()
# Out:
# []
# /home/michelle_m_kim/anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family [u'sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
sns.set(style='darkgrid', palette='muted', color_codes=True)
f, axes = plt.subplots(1,1, figsize=(12,8))
plt.title("Vocab Size Distributions by Gender",fontsize=16)
sns.distplot(with_gender_vocabs[with_gender_vocabs['M']==1]['VocabSize'],label='Male')
sns.distplot(with_gender_vocabs[with_gender_vocabs['M']==0]['VocabSize'],label='Female')
#plt.setp(axes, yticks=a)
plt.legend()
plt.plot()
# Out:
# []

# %%
with_gender_vocabs['Genre'].value_counts()
# Out:
# Drama        1087
# Crime         781
# Romance       722
# Sci-Fi        542
# Mystery       509
# Comedy        423
# Adventure     388
# Fantasy       338
# Horror        199
# War           170
# Action        166
# Western        37
# Music          36
# Thriller       35
# Animation      28
# Film-Noir      16
# Musical        12
# Name: Genre, dtype: int64

# %%
#model
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
data = np.random.random((1000,100))
labels = np.random.randint(2,size=(1000,1))
model = Sequential()
model.add(Dense(32, activation='relu', input_dim=100))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(data,labels,epochs=10,batch_size=32)
predictions = model.predict(data)

# %%
from urllib.request import urlopen
data = np.loadtxt(urlopen("http://archive.ics.uci.edu/ml/machine-learning-databases/pima-indians-diabetes/pima-indians-diabetes.data"),delimiter=",")
X = data[:,0:8]
y = data [:,8]

# %%
##Preprocessing

#Sequence Padding
from keras.preprocessing import sequence
x_train4 = sequence.pad_sequences(x_train4,maxlen=80)
x_test4 = sequence.pad_sequences(x_test4,maxlen=80)

#One-Hot Encoding
from keras.utils import to_categorical
Y_train = to_categorical(y_train, num_classes)
Y_test = to_categorical(y_test, num_classes)
Y_train3 = to_categorical(y_train3, num_classes)
Y_test3 = to_categorical(y_test3, num_classes)

#Train And Test Sets
from sklearn.model_selection import train_test_split
X_train5, X_test5, y_train5, y_test5 = train_test_split(X, y, test_size=0.33, random_state=42)

#Standardization/Normalization
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(x_train2)
standardized_X = scaler.transform(x_train2)
standardized_X_test = scaler.transform(x_test2)

# %%
#binary classification
from keras.layers import Dense
model.add(Dense(12, input_dim=8, kernel_initializer='uniform', activation='relu'))
model.add(Dense(8, kernel_initializer='uniform', activation='relu'))
model.add(Dense(1, kernel_initializer='uniform', activation='sigmoid'))
