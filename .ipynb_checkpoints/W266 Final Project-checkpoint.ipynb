# %% [markdown]
# ## W266 Final Project

# %%
import numpy as np
import pandas as pd
import re
import glob #this makes a list of all the files in a directory
from pandasql import sqldf
pysqldf = lambda q: sqldf(q, globals())

# %%
files_list = glob.glob("./data/imsdb_scenes_dialogs_nov_2015/dialogs/*/*_dialog.txt")

file_array = np.array(files_list)
files = pd.DataFrame(file_array.reshape(-1,1), columns=["FilePath"])

title_list = []
genre_list = []
for i in files.index:
    genretitle = files['FilePath'][i][45:] #get rid of all the ./data/imsdb...
    a, b = genretitle.split("/")
    genre_list.append(a)
    title_list.append(b[:-11]) #take off '_dialog.txt' from the file name
    
    
files['Genre']=genre_list
files['Title']=title_list

files
# Out:
#                                                FilePath    Genre  \
# 0     ./data/imsdb_scenes_dialogs_nov_2015/dialogs/A...   Action
# 1     ./data/imsdb_scenes_dialogs_nov_2015/dialogs/A...   Action
# 2     ./data/imsdb_scenes_dialogs_nov_2015/dialogs/A...   Action
# 3     ./data/imsdb_scenes_dialogs_nov_2015/dialogs/A...   Action
# 4     ./data/imsdb_scenes_dialogs_nov_2015/dialogs/A...   Action
# 5     ./data/imsdb_scenes_dialogs_nov_2015/dialogs/A...   Action
# 6     ./data/imsdb_scenes_dialogs_nov_2015/dialogs/A...   Action
# 7     ./data/imsdb_scenes_dialogs_nov_2015/dialogs/A...   Action
# 8     ./data/imsdb_scenes_dialogs_nov_2015/dialogs/A...   Action
# 9     ./data/imsdb_scenes_dialogs_nov_2015/dialogs/A...   Action
# 10    ./data/imsdb_scenes_dialogs_nov_2015/dialogs/A...   Action
# 11    ./data/imsdb_scenes_dialogs_nov_2015/dialogs/A...   Action
# 12    ./data/imsdb_scenes_dialogs_nov_2015/dialogs/A...   Action
# 13    ./data/imsdb_scenes_dialogs_nov_2015/dialogs/A...   Action
# 14    ./data/imsdb_scenes_dialogs_nov_2015/dialogs/A...   Action
# 15    ./data/imsdb_scenes_dialogs_nov_2015/dialogs/A...   Action
# 16    ./data/imsdb_scenes_dialogs_nov_2015/dialogs/A...   Action
# 17    ./data/imsdb_scenes_dialogs_nov_2015/dialogs/A...   Action
# 18    ./data/imsdb_scenes_dialogs_nov_2015/dialogs/A...   Action
# 19    ./data/imsdb_scenes_dialogs_nov_2015/dialogs/A...   Action
# 20    ./data/imsdb_scenes_dialogs_nov_2015/dialogs/A...   Action
# 21    ./data/imsdb_scenes_dialogs_nov_2015/dialogs/A...   Action
# 22    ./data/imsdb_scenes_dialogs_nov_2015/dialogs/A...   Action
# 23    ./data/imsdb_scenes_dialogs_nov_2015/dialogs/A...   Action
# 24    ./data/imsdb_scenes_dialogs_nov_2015/dialogs/A...   Action
# 25    ./data/imsdb_scenes_dialogs_nov_2015/dialogs/A...   Action
# 26    ./data/imsdb_scenes_dialogs_nov_2015/dialogs/A...   Action
# 27    ./data/imsdb_scenes_dialogs_nov_2015/dialogs/A...   Action
# 28    ./data/imsdb_scenes_dialogs_nov_2015/dialogs/A...   Action
# 29    ./data/imsdb_scenes_dialogs_nov_2015/dialogs/A...   Action
# ...                                                 ...      ...
# 2468  ./data/imsdb_scenes_dialogs_nov_2015/dialogs/W...      War
# 2469  ./data/imsdb_scenes_dialogs_nov_2015/dialogs/W...      War
# 2470  ./data/imsdb_scenes_dialogs_nov_2015/dialogs/W...      War
# 2471  ./data/imsdb_scenes_dialogs_nov_2015/dialogs/W...      War
# 2472  ./data/imsdb_scenes_dialogs_nov_2015/dialogs/W...      War
# 2473  ./data/imsdb_scenes_dialogs_nov_2015/dialogs/W...      War
# 2474  ./data/imsdb_scenes_dialogs_nov_2015/dialogs/W...      War
# 2475  ./data/imsdb_scenes_dialogs_nov_2015/dialogs/W...      War
# 2476  ./data/imsdb_scenes_dialogs_nov_2015/dialogs/W...      War
# 2477  ./data/imsdb_scenes_dialogs_nov_2015/dialogs/W...      War
# 2478  ./data/imsdb_scenes_dialogs_nov_2015/dialogs/W...      War
# 2479  ./data/imsdb_scenes_dialogs_nov_2015/dialogs/W...      War
# 2480  ./data/imsdb_scenes_dialogs_nov_2015/dialogs/W...      War
# 2481  ./data/imsdb_scenes_dialogs_nov_2015/dialogs/W...      War
# 2482  ./data/imsdb_scenes_dialogs_nov_2015/dialogs/W...      War
# 2483  ./data/imsdb_scenes_dialogs_nov_2015/dialogs/W...      War
# 2484  ./data/imsdb_scenes_dialogs_nov_2015/dialogs/W...      War
# 2485  ./data/imsdb_scenes_dialogs_nov_2015/dialogs/W...  Western
# 2486  ./data/imsdb_scenes_dialogs_nov_2015/dialogs/W...  Western
# 2487  ./data/imsdb_scenes_dialogs_nov_2015/dialogs/W...  Western
# 2488  ./data/imsdb_scenes_dialogs_nov_2015/dialogs/W...  Western
# 2489  ./data/imsdb_scenes_dialogs_nov_2015/dialogs/W...  Western
# 2490  ./data/imsdb_scenes_dialogs_nov_2015/dialogs/W...  Western
# 2491  ./data/imsdb_scenes_dialogs_nov_2015/dialogs/W...  Western
# 2492  ./data/imsdb_scenes_dialogs_nov_2015/dialogs/W...  Western
# 2493  ./data/imsdb_scenes_dialogs_nov_2015/dialogs/W...  Western
# 2494  ./data/imsdb_scenes_dialogs_nov_2015/dialogs/W...  Western
# 2495  ./data/imsdb_scenes_dialogs_nov_2015/dialogs/W...  Western
# 2496  ./data/imsdb_scenes_dialogs_nov_2015/dialogs/W...  Western
# 2497  ./data/imsdb_scenes_dialogs_nov_2015/dialogs/W...  Western
#
#                                       Title
# 0                                 15minutes
# 1                                      2012
# 2                           30minutesorless
# 3                                     48hrs
# 4                               abovethelaw
# 5                                  abyssthe
# 6                               airforceone
# 7                                    alien3
# 8                                     alien
# 9                                    aliens
# 10                           aloneinthedark
# 11        americanshaolinkingofkickboxersii
# 12                            apocalypsenow
# 13                               arcticblue
# 14                           armyofdarkness
# 15                                assassins
# 16    austinpowersinternationalmanofmystery
# 17           austinpowersthespywhoshaggedme
# 18                                   avatar
# 19                          avengersthe2012
# 20                              avengersthe
# 21                                backdraft
# 22                                  badboys
# 23                               badcountry
# 24                                  batman2
# 25                                   batman
# 26                                blackrain
# 27                                    blade
# 28                                  bladeii
# 29                              bladerunner
# ...                                     ...
# 2468                             coriolanus
# 2469                          deerhunterthe
# 2470                     fromheretoeternity
# 2471                            hotelrwanda
# 2472                   lastofthemohicansthe
# 2473                         lastsamuraithe
# 2474                  menwhostareatgoatsthe
# 2475                             patriotthe
# 2476                            pearlharbor
# 2477                             pianistthe
# 2478                                platoon
# 2479                      savingprivateryan
# 2480                         schindlerslist
# 2481                             threekings
# 2482                  threekingsspoilsofwar
# 2483                               valkyrie
# 2484                               warhorse
# 2485                      baddayatblackrock
# 2486                           bookofelithe
# 2487                       danceswithwolves
# 2488                        djangounchained
# 2489                             mariachiel
# 2490                              roughshod
# 2491                           searchersthe
# 2492                            stationwest
# 2493                        tallinthesaddle
# 2494                              tombstone
# 2495                               truegrit
# 2496                           wildbunchthe
# 2497                           wildwildwest
#
# [2498 rows x 3 columns]

# %%
movie1 = pd.read_fwf('./data/imsdb_scenes_dialogs_nov_2015/dialogs/Adventure/avatar_dialog.txt',
                    header=None, names=["RawLine"],encoding='utf')
movie2 = pd.read_fwf('./data/imsdb_scenes_dialogs_nov_2015/dialogs/Adventure/1492conquestofparadise_dialog.txt',
                    header=None, names=["RawLine"],encoding='utf')
movie3= pd.read_fwf('./data/imsdb_scenes_dialogs_nov_2015/dialogs/Adventure/antz_dialog.txt',
                   header=None, names=["RawLine"],encoding='utf')
movie3.head(n=15)
### suggestion: always read in movies as UTF-8 so we don't have weird “&amp;amp;”  instead of &
# Out:
#                                       RawLine
# "Antz", unknown draft                     NaN
# NaN                                       NaN
# A N T Z                                   NaN
# NaN                                       NaN
# CHARACTERS                             VOICES
# NaN                                       NaN
# Z (O.S.)                                  NaN
# NaN                                       NaN
# (over a dark screen)                      NaN
# NaN                                       NaN
# All my life, I've lived and worked in     NaN
# NaN                                       NaN
# the big city...                           NaN
# NaN                                       NaN
# soldier ants                              NaN

# %%
def is_name(string):
    #string1 = re.sub('(V.O.)|CUT TO:','',string)
    ### nikki edit
    string1 = re.sub(r'\W+', '', re.sub('(V.O.)|CUT TO:','',string))
    n = re.match('[A-Z][A-Z]+', string1)
    if n: return True
    else: return False

def is_speech(string):
    if not is_name(string):
        return True
    else: return False

def is_cutto(string):
    n = re.match('CUT TO', string)
    #print n
    if n: return True
    else: return False
    

def parse_movie(movie, genre, title):   
#   Args:
#     movie is a pandas dataframe of the raw movie script input
#     genre is the movie genre from the folder it's read in from
#     title is the title (file name prior to _dialog.txt)
#   Output:
#     a dataframe of the form below
    #print genre, title
    curr_char = None
    line = 0
    title_column=[]
    genre_column=[]
    char_column=[]
    speech_column=[]
    line_column=[] 
    for i in movie.index:
        title_column.append(title) 
        genre_column.append(genre) 
        current = str(movie['RawLine'][i])
        #current = str(current)
        #print current
        if current.lower() == 'nan':
            pass
            #print 'stop'

        elif is_cutto(current):
            char_column.append("")
            line_column.append(line)
            speech_column.append("")

        elif is_name(current):

            #starting a new character. hold onto this name for the next lines
            #until you see another new character name
            #also try to remove things that are irrelevant to the name 
            ### nikki edit: add in str.strip() in case voice over left whitespaces
            curr_char = re.sub('\(V.O.\)|V.O.|\(O.S.\)|O.S.|\(CONT\'D\)|CONT\'D','',current).strip()
            char_column.append(curr_char)

            line += 1
            line_column.append(line)
            speech_column.append("")

        elif is_speech(current):

            char_column.append(curr_char)
            line_column.append(line)
            speech_column.append(current)

    movie['Title']=title_column
    movie['Genre']=genre_column
    movie['Char']=char_column
    movie['LineID']=line_column
    movie['Speech']=speech_column

    return movie



parse_movie(movie1, 'Adventure', 'avatar')   
parse_movie(movie2, 'Adventure', '1492conquestofparadise')
#parse_movie(movie3, 'Adventure', 'antz')
#movie3.head(n=15)
    
#Intermediate dataframe should look something like this:

#RawLine                                  Title     Genre      Char   LineID     Speech

#JAKE (V.O.)                              Avatar    Adventure  JAKE   1 
#They can fix a spinal, if you've got the Avatar    Adventure  JAKE   1          They can fix... 
#money. But not on vet benefits, not in   Avatar    Adventure  JAKE   1          money. But not...


#And then hopefully we can eventually somehow aggregate by LineID to:

#Title   Genre      Char  Speech
#Avatar  Adventure  JAKE  They can fix a spinal, if you've got the money. But not on vet...
# Out:
#                                    RawLine                   Title      Genre  \
# 0                                  <b><!--  1492conquestofparadise  Adventure
# 1                    </b>if (window!= top)  1492conquestofparadise  Adventure
# 2          top.location.href=location.href  1492conquestofparadise  Adventure
# 3                                <b>// -->  1492conquestofparadise  Adventure
# 4                                     </b>  1492conquestofparadise  Adventure
# 5               1492: CONQUEST OF PARADISE  1492conquestofparadise  Adventure
# 6               1492: CONQUEST OF PARADISE  1492conquestofparadise  Adventure
# 7                                       by  1492conquestofparadise  Adventure
# 8                           Roselyne Bosch  1492conquestofparadise  Adventure
# 9                                  REVISED  1492conquestofparadise  Adventure
# 10                      September 23, 1991  1492conquestofparadise  Adventure
# 11                                 CUT TO:  1492conquestofparadise  Adventure
# 12                                 SANCHEZ  1492conquestofparadise  Adventure
# 13     Your Majesty would wish to know the  1492conquestofparadise  Adventure
# 14     true facts concerning the island of  1492conquestofparadise  Adventure
# 15      Hispanola, our first settlement in  1492conquestofparadise  Adventure
# 16       the New World, and the activities  1492conquestofparadise  Adventure
# 17      there of your servant, Christopher  1492conquestofparadise  Adventure
# 18     Columbus, Admiral of the Ocean Sea,  1492conquestofparadise  Adventure
# 19      Governor of that Island.  You will  1492conquestofparadise  Adventure
# 20            remember with what hopes and  1492conquestofparadise  Adventure
# 21    promises he beguiled us -- the truth  1492conquestofparadise  Adventure
# 22    is that he now presides over a state  1492conquestofparadise  Adventure
# 23       of chaos, degradation and madness  1492conquestofparadise  Adventure
# 24                       beyond imagining.  1492conquestofparadise  Adventure
# 25                                 SANCHEZ  1492conquestofparadise  Adventure
# 26     From the beginning, Columbus proved  1492conquestofparadise  Adventure
# 27       himself incapable of managing the  1492conquestofparadise  Adventure
# 28    affairs of the island.  He appointed  1492conquestofparadise  Adventure
# 29    his brothers to important positions,  1492conquestofparadise  Adventure
# ...                                    ...                     ...        ...
# 2162                             (smiling)  1492conquestofparadise  Adventure
# 2163  He never had one... except aboard my  1492conquestofparadise  Adventure
# 2164                                ships!  1492conquestofparadise  Adventure
# 2165                              FERNANDO  1492conquestofparadise  Adventure
# 2166  I want you to tell me everything you  1492conquestofparadise  Adventure
# 2167           remember, Father.  From the  1492conquestofparadise  Adventure
# 2168               beginning.  Everything.  1492conquestofparadise  Adventure
# 2169                              COLUMBUS  1492conquestofparadise  Adventure
# 2170                               Really?  1492conquestofparadise  Adventure
# 2171                               (pause)  1492conquestofparadise  Adventure
# 2172       God... I wouldn't know where to  1492conquestofparadise  Adventure
# 2173                   start... and yet...  1492conquestofparadise  Adventure
# 2174                              FERNANDO  1492conquestofparadise  Adventure
# 2175    Tell me the first thing that comes  1492conquestofparadise  Adventure
# 2176                         to your mind.  1492conquestofparadise  Adventure
# 2177                              COLUMBUS  1492conquestofparadise  Adventure
# 2178                         I remember...  1492conquestofparadise  Adventure
# 2179                               CUT TO:  1492conquestofparadise  Adventure
# 2180                               CUT TO:  1492conquestofparadise  Adventure
# 2181                         MUSIC BEGINS:  1492conquestofparadise  Adventure
# 2182    THE BIOGRAPHY FERNANDO WROTE ABOUT  1492conquestofparadise  Adventure
# 2183     HIS FATHER WAS FOUND BY CHANCE IN  1492conquestofparadise  Adventure
# 2184      VENICE.  ITS PUBLICATION IN 1571  1492conquestofparadise  Adventure
# 2185  CONTRIBUTED TO RESTORING THE NAME OF  1492conquestofparadise  Adventure
# 2186  CHRISTOPHER COLUMBUS, WHICH HAD BEEN  1492conquestofparadise  Adventure
# 2187                            FORGOTTEN.  1492conquestofparadise  Adventure
# 2188         IN 1511 DIEGO COLUMBUS BECAME  1492conquestofparadise  Adventure
# 2189            GOVERNOR OF SANTO DOMINGO.  1492conquestofparadise  Adventure
# 2190    COLUMBUS RESTS IN THE CATHEDRAL OF  1492conquestofparadise  Adventure
# 2191                SEVILLE, IN ANDALUSIA.  1492conquestofparadise  Adventure
#
#                                       Char  LineID  \
# 0                                     None       0
# 1                                     None       0
# 2                                     None       0
# 3                                     None       0
# 4                                     None       0
# 5                                     None       0
# 6                                     None       0
# 7                                     None       0
# 8                                     None       0
# 9                                  REVISED       1
# 10                                 REVISED       1
# 11                                               1
# 12                                 SANCHEZ       2
# 13                                 SANCHEZ       2
# 14                                 SANCHEZ       2
# 15                                 SANCHEZ       2
# 16                                 SANCHEZ       2
# 17                                 SANCHEZ       2
# 18                                 SANCHEZ       2
# 19                                 SANCHEZ       2
# 20                                 SANCHEZ       2
# 21                                 SANCHEZ       2
# 22                                 SANCHEZ       2
# 23                                 SANCHEZ       2
# 24                                 SANCHEZ       2
# 25                                 SANCHEZ       3
# 26                                 SANCHEZ       3
# 27                                 SANCHEZ       3
# 28                                 SANCHEZ       3
# 29                                 SANCHEZ       3
# ...                                    ...     ...
# 2162                              COLUMBUS     643
# 2163                              COLUMBUS     643
# 2164                              COLUMBUS     643
# 2165                              FERNANDO     644
# 2166                              FERNANDO     644
# 2167                              FERNANDO     644
# 2168                              FERNANDO     644
# 2169                              COLUMBUS     645
# 2170                              COLUMBUS     645
# 2171                              COLUMBUS     645
# 2172                              COLUMBUS     645
# 2173                              COLUMBUS     645
# 2174                              FERNANDO     646
# 2175                              FERNANDO     646
# 2176                              FERNANDO     646
# 2177                              COLUMBUS     647
# 2178                              COLUMBUS     647
# 2179                                           647
# 2180                                           647
# 2181                         MUSIC BEGINS:     648
# 2182    THE BIOGRAPHY FERNANDO WROTE ABOUT     649
# 2183     HIS FATHER WAS FOUND BY CHANCE IN     650
# 2184      VENICE.  ITS PUBLICATION IN 1571     651
# 2185  CONTRIBUTED TO RESTORING THE NAME OF     652
# 2186  CHRISTOPHER COLUMBUS, WHICH HAD BEEN     653
# 2187                            FORGOTTEN.     654
# 2188         IN 1511 DIEGO COLUMBUS BECAME     655
# 2189            GOVERNOR OF SANTO DOMINGO.     656
# 2190    COLUMBUS RESTS IN THE CATHEDRAL OF     657
# 2191                SEVILLE, IN ANDALUSIA.     658
#
#                                     Speech
# 0                                  <b><!--
# 1                    </b>if (window!= top)
# 2          top.location.href=location.href
# 3                                <b>// -->
# 4                                     </b>
# 5               1492: CONQUEST OF PARADISE
# 6               1492: CONQUEST OF PARADISE
# 7                                       by
# 8                           Roselyne Bosch
# 9
# 10                      September 23, 1991
# 11
# 12
# 13     Your Majesty would wish to know the
# 14     true facts concerning the island of
# 15      Hispanola, our first settlement in
# 16       the New World, and the activities
# 17      there of your servant, Christopher
# 18     Columbus, Admiral of the Ocean Sea,
# 19      Governor of that Island.  You will
# 20            remember with what hopes and
# 21    promises he beguiled us -- the truth
# 22    is that he now presides over a state
# 23       of chaos, degradation and madness
# 24                       beyond imagining.
# 25
# 26     From the beginning, Columbus proved
# 27       himself incapable of managing the
# 28    affairs of the island.  He appointed
# 29    his brothers to important positions,
# ...                                    ...
# 2162                             (smiling)
# 2163  He never had one... except aboard my
# 2164                                ships!
# 2165
# 2166  I want you to tell me everything you
# 2167           remember, Father.  From the
# 2168               beginning.  Everything.
# 2169
# 2170                               Really?
# 2171                               (pause)
# 2172       God... I wouldn't know where to
# 2173                   start... and yet...
# 2174
# 2175    Tell me the first thing that comes
# 2176                         to your mind.
# 2177
# 2178                         I remember...
# 2179
# 2180
# 2181
# 2182
# 2183
# 2184
# 2185
# 2186
# 2187
# 2188
# 2189
# 2190
# 2191
#
# [2192 rows x 6 columns]

# %%
movie1['Char'].value_counts()
# Out:
# JAKE                                       757
# GRACE                                      434
# QUARITCH                                   253
# NEYTIRI                                    186
# SELFRIDGE                                  137
# NORM                                       123
# (SUBTITLED)                                119
# TRUDY                                       93
#                                             87
# MAX                                         69
# MO'AT                                       63
# TSU'TEY                                     55
# WAINFLEET                                   33
# EYTUKAN                                     18
# PILOT                                       17
# MED TECH                                    13
# CREW CHIEF                                  13
# TROOPER                                     11
# JAKE (RECORDED)                             10
# (QUIETLY)                                    8
# VOICE                                        8
# (ANGUISHED)                                  8
# (MORE)                                       8
# (WHISPERING)                                 8
# TRUDY (INTERCOM)                             7
# GRACE (cont'd)                               7
# (NA'VI)                                      7
# DISSOLVE TO:                                 6
# AGENT 1                                      6
# OPERATOR                                     6
#                                           ...
# (MILDLY)                                     3
# I See you.                                   2
# FIKE                                         2
# PIL                                          2
# (ICY)                                        2
# WHAM! Total frickin' yard sale. Ate the      2
# (PLEADING)                                   2
# WHOO-HOOOO!                                  2
# SHOULDER)                                    2
# MAN                                          2
# (INNOCENTLY)                                 2
# (YELLING)                                    2
# (SOFTENING)                                  2
# GUNNER                                       2
# (FRUSTRATED)                                 2
# I See you, Doctor Grace Augustine.           2
# (LAUGHING)                                   2
# AGENT 2                                      2
# (TURNING)                                    2
# GUNSHIP PILOT                                2
# (SHOUTING)                                   2
# (TRANSLATING)                                2
# SLOW DISSOLVE TO:                            1
# I See you, Tsu'tey te Rongloa Ateyitan.      1
# THEM--                                       1
# HERE--                                       1
# NEVER!                                       1
# TSUTEY                                       1
# I See you, Jakesully.                        1
# I See you, Neytiri Mo'at'ite.                1
# Name: Char, Length: 81, dtype: int64

# %%
movie1[movie1["Char"] == 'GRACE']
# Out:
#                                          RawLine   Title      Genre   Char  \
# 238                                        GRACE  avatar  Adventure  GRACE
# 245                                        GRACE  avatar  Adventure  GRACE
# 246          Norm. I hear good things about you.  avatar  Adventure  GRACE
# 247                            How's your Na'vi?  avatar  Adventure  GRACE
# 248                                          14.  avatar  Adventure  GRACE
# 253                                        GRACE  avatar  Adventure  GRACE
# 261                                        GRACE  avatar  Adventure  GRACE
# 262                            (turning to Jake)  avatar  Adventure  GRACE
# 263        Yeah, yeah, I know who you are, and I  avatar  Adventure  GRACE
# 264         don't need you. I need your brother.  avatar  Adventure  GRACE
# 265                                     (to Max)  avatar  Adventure  GRACE
# 266        You know -- the PhD who trained three  avatar  Adventure  GRACE
# 267                      years for this mission.  avatar  Adventure  GRACE
# 271                                        GRACE  avatar  Adventure  GRACE
# 272   How much lab training have you had?   Ever  avatar  Adventure  GRACE
# 273                     run a gas chromatograph?  avatar  Adventure  GRACE
# 276                                        GRACE  avatar  Adventure  GRACE
# 277                  Any actual lab work at all?  avatar  Adventure  GRACE
# 280                                        GRACE  avatar  Adventure  GRACE
# 281      You see? You see? They're pissing on us  avatar  Adventure  GRACE
# 282      without even the courtesy of calling it  avatar  Adventure  GRACE
# 283                                        rain.  avatar  Adventure  GRACE
# 284                               (turning away)  avatar  Adventure  GRACE
# 285                      I'm going to Selfridge.  avatar  Adventure  GRACE
# 286                                          15.  avatar  Adventure  GRACE
# 293                                        GRACE  avatar  Adventure  GRACE
# 294        Parker, I used to think it was benign  avatar  Adventure  GRACE
# 295                neglect, but now I see you're  avatar  Adventure  GRACE
# 296                   intentionally screwing us.  avatar  Adventure  GRACE
# 300                                        GRACE  avatar  Adventure  GRACE
# ...                                          ...     ...        ...    ...
# 2014                          you're about to --  avatar  Adventure  GRACE
# 2020                                       GRACE  avatar  Adventure  GRACE
# 2021       For God's sake, there are children in  avatar  Adventure  GRACE
# 2022                              there. Babies!  avatar  Adventure  GRACE
# 2150                                       GRACE  avatar  Adventure  GRACE
# 2151            They never wanted us to succeed.  avatar  Adventure  GRACE
# 2173                                       GRACE  avatar  Adventure  GRACE
# 2174                                   I'm free.  avatar  Adventure  GRACE
# 2194                                       GRACE  avatar  Adventure  GRACE
# 2195                    Do what he goddamn says!  avatar  Adventure  GRACE
# 2201                                       GRACE  avatar  Adventure  GRACE
# 2202                     Aaahh, crap. Not again.  avatar  Adventure  GRACE
# 2203                                       GRACE  avatar  Adventure  GRACE
# 2204            This is gonna ruin my whole day.  avatar  Adventure  GRACE
# 2224                                       GRACE  avatar  Adventure  GRACE
# 2225               Forget it, it doesn't matter.  avatar  Adventure  GRACE
# 2302                                       GRACE  avatar  Adventure  GRACE
# 2303                          (with a wan smile)  avatar  Adventure  GRACE
# 2304                I need to take some samples.  avatar  Adventure  GRACE
# 2319                                       GRACE  avatar  Adventure  GRACE
# 2320    I -- always held back. But you gave them  avatar  Adventure  GRACE
# 2321         your heart. I'm proud of you, Jake.  avatar  Adventure  GRACE
# 2322                                        121.  avatar  Adventure  GRACE
# 2323                                       GRACE  avatar  Adventure  GRACE
# 2324  Help them.     You do whatever it takes. Y  avatar  Adventure  GRACE
# 2325                                    hear me?  avatar  Adventure  GRACE
# 2328                                       GRACE  avatar  Adventure  GRACE
# 2329                        I'm with her Jake --  avatar  Adventure  GRACE
# 2330                         (an amazed whisper)  avatar  Adventure  GRACE
# 2331                            -- she's real --  avatar  Adventure  GRACE
#
#       LineID                                      Speech
# 238       61
# 245       64
# 246       64         Norm. I hear good things about you.
# 247       64                           How's your Na'vi?
# 248       64                                         14.
# 253       66
# 261       71
# 262       71                           (turning to Jake)
# 263       71       Yeah, yeah, I know who you are, and I
# 264       71        don't need you. I need your brother.
# 265       71                                    (to Max)
# 266       71       You know -- the PhD who trained three
# 267       71                     years for this mission.
# 271       73
# 272       73  How much lab training have you had?   Ever
# 273       73                    run a gas chromatograph?
# 276       75
# 277       75                 Any actual lab work at all?
# 280       77
# 281       77     You see? You see? They're pissing on us
# 282       77     without even the courtesy of calling it
# 283       77                                       rain.
# 284       77                              (turning away)
# 285       77                     I'm going to Selfridge.
# 286       77                                         15.
# 293       80
# 294       80       Parker, I used to think it was benign
# 295       80               neglect, but now I see you're
# 296       80                  intentionally screwing us.
# 300       82
# ...      ...                                         ...
# 2014     643                          you're about to --
# 2020     645
# 2021     645       For God's sake, there are children in
# 2022     645                              there. Babies!
# 2150     693
# 2151     693            They never wanted us to succeed.
# 2173     701
# 2174     701                                   I'm free.
# 2194     708
# 2195     708                    Do what he goddamn says!
# 2201     711
# 2202     711                     Aaahh, crap. Not again.
# 2203     712
# 2204     712            This is gonna ruin my whole day.
# 2224     720
# 2225     720               Forget it, it doesn't matter.
# 2302     749
# 2303     749                          (with a wan smile)
# 2304     749                I need to take some samples.
# 2319     756
# 2320     756    I -- always held back. But you gave them
# 2321     756         your heart. I'm proud of you, Jake.
# 2322     756                                        121.
# 2323     757
# 2324     757  Help them.     You do whatever it takes. Y
# 2325     757                                    hear me?
# 2328     759
# 2329     759                        I'm with her Jake --
# 2330     759                         (an amazed whisper)
# 2331     759                            -- she's real --
#
# [434 rows x 6 columns]

# %%
movie2.head(15)
# Out:
#                                 RawLine                   Title      Genre  \
# 0                               <b><!--  1492conquestofparadise  Adventure
# 1                 </b>if (window!= top)  1492conquestofparadise  Adventure
# 2       top.location.href=location.href  1492conquestofparadise  Adventure
# 3                             <b>// -->  1492conquestofparadise  Adventure
# 4                                  </b>  1492conquestofparadise  Adventure
# 5            1492: CONQUEST OF PARADISE  1492conquestofparadise  Adventure
# 6            1492: CONQUEST OF PARADISE  1492conquestofparadise  Adventure
# 7                                    by  1492conquestofparadise  Adventure
# 8                        Roselyne Bosch  1492conquestofparadise  Adventure
# 9                               REVISED  1492conquestofparadise  Adventure
# 10                   September 23, 1991  1492conquestofparadise  Adventure
# 11                              CUT TO:  1492conquestofparadise  Adventure
# 12                              SANCHEZ  1492conquestofparadise  Adventure
# 13  Your Majesty would wish to know the  1492conquestofparadise  Adventure
# 14  true facts concerning the island of  1492conquestofparadise  Adventure
#
#        Char  LineID                               Speech
# 0      None       0                              <b><!--
# 1      None       0                </b>if (window!= top)
# 2      None       0      top.location.href=location.href
# 3      None       0                            <b>// -->
# 4      None       0                                 </b>
# 5      None       0           1492: CONQUEST OF PARADISE
# 6      None       0           1492: CONQUEST OF PARADISE
# 7      None       0                                   by
# 8      None       0                       Roselyne Bosch
# 9   REVISED       1
# 10  REVISED       1                   September 23, 1991
# 11                1
# 12  SANCHEZ       2
# 13  SANCHEZ       2  Your Majesty would wish to know the
# 14  SANCHEZ       2  true facts concerning the island of

# %%
movie2['Char'].value_counts()
# Out:
# COLUMBUS                                825
# SANCHEZ                                 212
# MARCHENA                                122
# PINZON                                  100
# AROJAZ                                  100
# FERNANDO                                 92
# ISABEL                                   92
# SANTANGEL                                55
#                                          51
# MOXICA                                   51
# AL                                       44
# UTAPAN                                   40
# BEATRIX                                  38
# MENDEZ                                   32
# BOBADILLA                                30
# BARTOLOME                                29
# BROTHER BUYL                             28
# GIACOMO                                  24
# SAILOR                                   22
# ADMINISTRATOR                            21
# DIEGO                                    20
# SOLDIER                                  14
# DIEGO DE DEZA                            11
# DUENA                                    11
# TRANSLATOR                               10
# GUEVARA                                   8
# DOCTOR                                    7
# OFFICER                                   7
# VICUNA                                    6
# ASSISTANT                                 6
#                                        ...
# SHIP'S BOY                                5
# DOCTOR CHANCA                             5
# NO...!  I have waited too long,           5
# INDIANS                                   4
# COOK                                      4
# NOBLEMAN                                  3
# MASTER                                    3
# SAILOR'S VOICE                            2
# MAN                                       2
# REVISED                                   2
# A MAN IN BLACK                            2
# OLD INDIAN                                2
# HERNANDO DE TALAVERA                      2
# I... I have to see Mendez.                1
# SLOW DISSOLVE TO:                         1
# SEVILLE, IN ANDALUSIA.                    1
# IN 1511 DIEGO COLUMBUS BECAME             1
# VENICE.  ITS PUBLICATION IN 1571          1
# COLUMBUS RESTS IN THE CATHEDRAL OF        1
# HIS FATHER WAS FOUND BY CHANCE IN         1
# I WON'T!                                  1
# MUSIC BEGINS:                             1
# GOVERNOR OF SANTO DOMINGO.                1
# IF-GOD-WILLS-IT!                          1
# CHRISTOPHER COLUMBUS, WHICH HAD BEEN      1
# TIERRA...!  TIERRA!                       1
# FORGOTTEN.                                1
# CONTRIBUTED TO RESTORING THE NAME OF      1
# THE BIOGRAPHY FERNANDO WROTE ABOUT        1
# YEEEEEEES!                                1
# Name: Char, Length: 63, dtype: int64

# %%
### keep only characters with at least 20 lines per movie

def top_chars(df, threshold = 20):
    #dframe = df
#     print dframe.head()
#     print type(dframe)
    threshold = threshold
    char_list = pd.DataFrame(df["Char"].value_counts())
    to_remove = char_list[char_list['Char'] <= threshold].index
    cl1 = char_list.drop(to_remove)
    cl1['line_count'] = cl1['Char']
    cl1['Char'] = cl1.index
    #char_list.reset_index(drop=True)
    query = 'SELECT d.*, c.line_count FROM df d INNER JOIN cl1 c on d.Char = c.Char'
    enriched_df = sqldf(query, locals())
    enriched_df = enriched_df[enriched_df['Char'] != '']
    #return cl1.head(20)
    return enriched_df

def pipeline(df,threshold=20):
    ### before top chars, we can add something about a proper title finder
    tc = top_chars(df, threshold)
    
    ### add something about the gender id
    ### add something about vocab enrichment
    ### output should be called final_df
    final_df = tc
    return tc
    

enriched_movie2 = pipeline(movie2)

# %%
enriched_movie2.head()
# Out:
#                                RawLine                   Title      Genre  \
# 1                              SANCHEZ  1492conquestofparadise  Adventure
# 2  Your Majesty would wish to know the  1492conquestofparadise  Adventure
# 3  true facts concerning the island of  1492conquestofparadise  Adventure
# 4   Hispanola, our first settlement in  1492conquestofparadise  Adventure
# 5    the New World, and the activities  1492conquestofparadise  Adventure
#
#       Char  LineID                               Speech  line_count
# 1  SANCHEZ       2                                              212
# 2  SANCHEZ       2  Your Majesty would wish to know the         212
# 3  SANCHEZ       2  true facts concerning the island of         212
# 4  SANCHEZ       2   Hispanola, our first settlement in         212
# 5  SANCHEZ       2    the New World, and the activities         212

# %%
enriched_movie2['Char'].value_counts()
# Out:
# COLUMBUS         825
# SANCHEZ          212
# MARCHENA         122
# AROJAZ           100
# PINZON           100
# FERNANDO          92
# ISABEL            92
# SANTANGEL         55
# MOXICA            51
# AL                44
# UTAPAN            40
# BEATRIX           38
# MENDEZ            32
# BOBADILLA         30
# BARTOLOME         29
# BROTHER BUYL      28
# GIACOMO           24
# SAILOR            22
# ADMINISTRATOR     21
# Name: Char, dtype: int64

# %%
enriched_movie1 = pipeline(movie1)

# %%
enriched_movie1.head()
# Out:
#                                     RawLine   Title      Genre  Char  LineID  \
# 1                               JAKE (V.O.)  avatar  Adventure  JAKE       4
# 2  They can fix a spinal, if you've got the  avatar  Adventure  JAKE       4
# 3    money. But not on vet benefits, not in  avatar  Adventure  JAKE       4
# 4                             this economy.  avatar  Adventure  JAKE       4
# 5                               JAKE (V.O.)  avatar  Adventure  JAKE       6
#
#                                      Speech  line_count
# 1                                                   757
# 2  They can fix a spinal, if you've got the         757
# 3    money. But not on vet benefits, not in         757
# 4                             this economy.         757
# 5                                                   757

# %%
enriched_movie1['Char'].value_counts()
# Out:
# JAKE           757
# GRACE          434
# QUARITCH       253
# NEYTIRI        186
# SELFRIDGE      137
# NORM           123
# (SUBTITLED)    119
# TRUDY           93
# MAX             69
# MO'AT           63
# TSU'TEY         55
# WAINFLEET       33
# Name: Char, dtype: int64

# %%
not_working=[]
char_list_to_label=[]

for i in files_list:
    title = i.split('/')[5].split('_')[0]
    genre = i.split('/')[4]
    if genre=='Crime':
        print i
        #print genre
        title = title.strip()
        genre = genre.strip()
        movie = pd.read_fwf("%s" % i,header=None, names=["RawLine"],encoding='utf')
        #print movie
        try:
            parsed = parse_movie(movie, genre, title)
            #print parsed.head()
            final_df = pipeline(movie)
            char_list = final_df.drop_duplicates(subset='Char',keep='last')[['Char','Genre','Title','line_count']]
            char_list_to_label.append(char_list)
        except:
            not_working.append((genre,title))
        #print final_df.head()
        print "processing next movie"
chars= pd.concat(char_list_to_label)
chars.to_csv('OutputCrimeCharacters.csv', index=False)
print not_working
print chars
# Out:
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/15minutes_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/44inchchest_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/absolutepower_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/afewgoodmen_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/aliennation_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/americangangster_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/americanhistoryx_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/americanhustle_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/americanthe_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/analyzethat_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/analyzethis_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/antitrust_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/arsenicandoldlace_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/badcountry_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/badlieutenant_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/badsanta_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/basicinstinct_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/batman2_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/batman_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/bigwhitethe_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/birthdaygirl_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/blackdahliathe_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/blackrain_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/blingringthe_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/bloodandwine_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/blow_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/bluevelvet_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/bodyheat_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/bonnieandclyde_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/boondocksaints2allsaintsday_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/boondocksaintsthe_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/bottlerocket_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/bound_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/bountyhunterthe_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/brothersbloomthe_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/burnafterreading_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/capote_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/casino_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/catchmeifyoucan_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/cecilbdemented_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/cellular_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/changeling_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/chaos_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/chinatown_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/colombiana_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/confessionsofadangerousmind_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/confidence_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/copycat_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/cradle2thegrave_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/crank_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/crimespree_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/croupier_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/crowsalvationthe_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/darkknightrisesthe_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/darkman_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/datenight_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/deathtosmoochy_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/deepcover_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/departedthe_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/devilinabluedress_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/donniebrasco_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/doubleindemnity_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/drive_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/driveangry_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/easternpromises_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/entrapment_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/extract_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/faceoff_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/fargo_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/fatalinstinct_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/fracture_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/frenchconnectionthe_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/frozenriver_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/gangrelated_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/getawaythe_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/getcarter_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/girlwiththedragontattoothe_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/go_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/godfather_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/godfatherpartii_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/godfatherpartiiithe_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/gonein60seconds_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/griftersthe_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/grossepointblank_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/hackers_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/hangoverthe_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/hanna_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/hardrain_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/heat_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/heist_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/henryscrime_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/horriblebosses_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/hostage_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/hudsonhawk_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/insomnia_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/inthebedroom_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/intolerablecruelty_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/italianjobthe_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/jackiebrown_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/jfk_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/judgedredd_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/kalifornia_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/killbillvolume12_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/killingzoe_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/kingofcomedythe_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/klute_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/laconfidential_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/ladykillersthe_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/lawabidingcitizen_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/lifeofdavidgalethe_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/limeythe_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/lincolnlawyerthe_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/lonestar_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/looper_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/lordofwar_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/losersthe_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/machinegunpreacher_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/manhattanmurdermystery_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/manonfire_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/manwhowasnttherethe_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/mariachiel_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/maxpayne_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/meanstreets_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/mechanicthe_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/miamivice_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/midnightexpress_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/millerscrossing_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/minisfirsttime_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/minorityreport_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/mrbrooks_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/naturalbornkillers_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/nextthreedaysthe_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/nickoftime_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/ninjaassassin_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/observeandreport_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/oceanseleven_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/oceanstwelve_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/onlygodforgives_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/outofsight_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/panicroom_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/perfectworlda_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/pineappleexpress_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/pointbreak_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/pulpfiction_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/reindeergames_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/reservoirdogs_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/rocknrolla_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/romeojuliet_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/ronin_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/rushhour2_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/rushhour_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/saltonseathe_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/saw_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/scarface_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/sdarko_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/serialmom_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/sherlockholmes_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/silenceofthelambs_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/sisteract_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/slumdogmillionaire_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/smokinaces_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/snatch_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/someonetowatchoverme_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/spartan_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/stingthe_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/strangedays_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/suspectzero_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/takinglives_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/takingofpelhamonetwothreethe_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/talentedmrripleythe_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/taxidriver_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/thelmalouise_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/thunderheart_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/ticker_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/traffic_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/usualsuspectsthe_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/visitorthe_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/wallstreet_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/weownthenight_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/whileshewasout_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/whitejazz_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/whiteout_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/whiteribbonthe_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/wildatheart_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/wildthings_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/witness_dialog.txt
# processing next movie
# ./data/imsdb_scenes_dialogs_nov_2015/dialogs/Crime/wolfofwallstreetthe_dialog.txt
# processing next movie
# [('Crime', 'absolutepower'), ('Crime', 'americangangster'), ('Crime', 'analyzethis'), ('Crime', 'badsanta'), ('Crime', 'bigwhitethe'), ('Crime', 'blingringthe'), ('Crime', 'bodyheat'), ('Crime', 'bottlerocket'), ('Crime', 'brothersbloomthe'), ('Crime', 'capote'), ('Crime', 'catchmeifyoucan'), ('Crime', 'cecilbdemented'), ('Crime', 'chaos'), ('Crime', 'crank'), ('Crime', 'devilinabluedress'), ('Crime', 'driveangry'), ('Crime', 'easternpromises'), ('Crime', 'extract'), ('Crime', 'frozenriver'), ('Crime', 'girlwiththedragontattoothe'), ('Crime', 'go'), ('Crime', 'gonein60seconds'), ('Crime', 'heat'), ('Crime', 'henryscrime'), ('Crime', 'horriblebosses'), ('Crime', 'hudsonhawk'), ('Crime', 'inthebedroom'), ('Crime', 'lawabidingcitizen'), ('Crime', 'lincolnlawyerthe'), ('Crime', 'meanstreets'), ('Crime', 'mechanicthe'), ('Crime', 'minisfirsttime'), ('Crime', 'naturalbornkillers'), ('Crime', 'nextthreedaysthe'), ('Crime', 'ninjaassassin'), ('Crime', 'oceanseleven'), ('Crime', 'outofsight'), ('Crime', 'perfectworlda'), ('Crime', 'pulpfiction'), ('Crime', 'reservoirdogs'), ('Crime', 'rocknrolla'), ('Crime', 'scarface'), ('Crime', 'sherlockholmes'), ('Crime', 'slumdogmillionaire'), ('Crime', 'talentedmrripleythe'), ('Crime', 'traffic'), ('Crime', 'usualsuspectsthe'), ('Crime', 'whileshewasout'), ('Crime', 'whitejazz'), ('Crime', 'wildthings'), ('Crime', 'wolfofwallstreetthe')]
#                      Char  Genre        Title  line_count
# 105   IMMIGRATION OFFICER  Crime    15minutes          56
# 375                 MILOS  Crime    15minutes          32
# 595                MUGGER  Crime    15minutes          22
# 785        ROBERT HAWKINS  Crime    15minutes          36
# 789        STEPHEN GELLER  Crime    15minutes          30
# 847                 HONEY  Crime    15minutes          32
# 1206                 ROSE  Crime    15minutes          45
# 1971                EDDIE  Crime    15minutes         532
# 2222                  MAX  Crime    15minutes          27
# 2226               KORFIN  Crime    15minutes         103
# 2476                TOMMY  Crime    15minutes          44
# 2507                 LEON  Crime    15minutes         111
# 2694                DUFFY  Crime    15minutes          93
# 2718                STERN  Crime    15minutes          22
# 2732               DAPHNE  Crime    15minutes         121
# 2758    HAWKINS (ON T.V.)  Crime    15minutes          24
# 2825               CUTLER  Crime    15minutes         140
# 2855                 EMIL  Crime    15minutes         426
# 2864              HAWKINS  Crime    15minutes         118
# 2868                 OLEG  Crime    15minutes         165
# 2875                JORDY  Crime    15minutes         504
# 2895            NICOLETTE  Crime    15minutes         213
# 37               PROLOGUE  Crime  44inchchest          38
# 76         CONTINUED: (2)  Crime  44inchchest          38
# 219                 BIGGY  Crime  44inchchest          32
# 761        ARCHIE'S VOICE  Crime  44inchchest          39
# 799                 TIPPI  Crime  44inchchest          21
# 1667         COLIN (CONT)  Crime  44inchchest          69
# 1951            OMP VOICE  Crime  44inchchest          22
# 2484               (MORE)  Crime  44inchchest          30
# ...                   ...    ...          ...         ...
# 1752                 CHET  Crime  wildatheart          30
# 1861                ROACH  Crime  wildatheart          32
# 2297             REPORTER  Crime  wildatheart          26
# 2354         MR. REINDEER  Crime  wildatheart          31
# 2504          DROP SHADOW  Crime  wildatheart          46
# 2529               REGGIE  Crime  wildatheart         114
# 2534              JOHNNIE  Crime  wildatheart         195
# 2543                JUANA  Crime  wildatheart          57
# 2711                 GIRL  Crime  wildatheart          21
# 2806                  RED  Crime  wildatheart          22
# 2946                BUDDY  Crime  wildatheart          42
# 2950               SPARKY  Crime  wildatheart          35
# 3533              PERDITA  Crime  wildatheart          65
# 3538                BOBBY  Crime  wildatheart         278
# 3556               SANTOS  Crime  wildatheart         136
# 3596             MARIETTA  Crime  wildatheart         329
# 3697                 PACE  Crime  wildatheart          32
# 3761               SAILOR  Crime  wildatheart         940
# 3762                 LULA  Crime  wildatheart        1076
# 840             STOLTZFUS  Crime      witness          29
# 873                ELAINE  Crime      witness         104
# 1334               CARTER  Crime      witness          56
# 1466          HOCHSTETLER  Crime      witness          42
# 1498            LOCAL MAN  Crime      witness          21
# 1589         UNDERSHERIFF  Crime      witness          21
# 1716            SCHAEFFER  Crime      witness         203
# 1724               SAMUEL  Crime      witness          62
# 1731                 BOOK  Crime      witness         562
# 1733               RACHEL  Crime      witness         480
# 1736                  ELI  Crime      witness         157
#
# [2271 rows x 4 columns]

# %%
print not_working
# Out:
# [('Western', 'djangounchained'), ('Western', 'bookofelithe'), ('Western', 'wildwildwest')]

# %%
print not_working
# Out:
# [('Action', 'kingkong'), ('Action', 'xmen'), ('Action', 'threemusketeersthe'), ('Action', 'codeofsilence'), ('Action', 'timemachinethe'), ('Action', 'scarface'), ('Action', 'missionimpossible'), ('Action', 'oblivion'), ('Action', 'wildthingsdiamondsintherough'), ('Action', 'collateraldamage'), ('Action', 'bookofelithe'), ('Action', 'iamnumberfour'), ('Action', 'diehard2'), ('Action', 'thor'), ('Action', 'starshiptroopers'), ('Action', 'thunderbirds'), ('Action', 'crouchingtigerhiddendragon'), ('Action', 'clashofthetitans'), ('Action', 'virtuosity'), ('Action', 'commando'), ('Action', 'apocalypsenow'), ('Action', 'tmnt'), ('Action', 'deeprising'), ('Action', 'driveangry'), ('Action', 'heat'), ('Action', 'highlander'), ('Action', 'meninblack3'), ('Action', 'rush'), ('Action', 'threekings'), ('Action', 'blade'), ('Action', 'mechanicthe'), ('Action', 'thingthe'), ('Action', 'perfectworlda'), ('Action', 'indianajonesandthetempleofdoom'), ('Action', 'warrior'), ('Action', 'tron'), ('Action', 'hardtokill'), ('Action', 'constantine'), ('Action', 'godzilla'), ('Action', 'postmanthe'), ('Action', 'wildwildwest'), ('Action', 'enemyofthestate'), ('Action', 'sherlockholmes'), ('Action', 'startrekgenerations'), ('Action', 'swordfish'), ('Action', 'gamer'), ('Action', 'bourneultimatumthe'), ('Action', 'startrek'), ('Action', 'crank'), ('Action', 'jurassicpark'), ('Action', 'planetoftheapesthe'), ('Action', 'hudsonhawk'), ('Action', 'reservoirdogs'), ('Action', 'truelies'), ('Action', 'naturalbornkillers'), ('Action', 'twins'), ('Action', 'startrekfirstcontact'), ('Action', 'huntforredoctoberthe'), ('Action', 'austinpowersinternationalmanofmystery'), ('Action', 'pulpfiction'), ('Action', 'cowboysaliens'), ('Action', 'assassins'), ('Action', 'threekingsspoilsofwar'), ('Action', 'missionimpossibleii'), ('Action', 'badboys'), ('Action', 'pandorum'), ('Action', 'cirquedufreakthevampiresassistant'), ('Action', 'ninjaassassin'), ('Action', 'chaos'), ('Action', 'aloneinthedark'), ('Action', 'xfilesfightthefuturethe'), ('Action', 'rocknrolla'), ('Action', 'gonein60seconds'), ('Action', 'freddyvsjason'), ('Action', 'mightymorphinpowerrangersthemovie'), ('Action', 'priest'), ('Action', 'startrekiithewrathofkhan'), ('Action', 'debtthe')]

# %%
print not_working
# Out:
# [('War', 'apocalypsenow'), ('War', 'lastofthemohicansthe'), ('War', 'menwhostareatgoatsthe'), ('War', 'threekings'), ('War', 'threekingsspoilsofwar'), ('War', 'valkyrie')]

# %%
print not_working
# Out:
# [('Thriller', '12monkeys'), ('Thriller', 'absolutepower'), ('Thriller', 'adjustmentbureauthe'), ('Thriller', 'aloneinthedark'), ('Thriller', 'assassins'), ('Thriller', 'bodyheat'), ('Thriller', 'bookofelithe'), ('Thriller', 'bourneultimatumthe'), ('Thriller', 'cecilbdemented'), ('Thriller', 'chaos'), ('Thriller', 'cirquedufreakthevampiresassistant'), ('Thriller', 'collateraldamage'), ('Thriller', 'commando'), ('Thriller', 'constantine'), ('Thriller', 'cowboysaliens'), ('Thriller', 'crank'), ('Thriller', 'debtthe'), ('Thriller', 'deeprising'), ('Thriller', 'devilinabluedress'), ('Thriller', 'devilsadvocate'), ('Thriller', 'diehard2'), ('Thriller', 'disturbia'), ('Thriller', 'easternpromises'), ('Thriller', 'enemyofthestate'), ('Thriller', 'enough'), ('Thriller', 'freddyvsjason'), ('Thriller', 'fridaythe13th'), ('Thriller', 'frightnight1985'), ('Thriller', 'frozen'), ('Thriller', 'gamer'), ('Thriller', 'gamethe'), ('Thriller', 'gattaca'), ('Thriller', 'godzilla'), ('Thriller', 'heat'), ('Thriller', 'hellraiserdeader'), ('Thriller', 'hillshaveeyesthe'), ('Thriller', 'huntforredoctoberthe'), ('Thriller', 'iamnumberfour'), ('Thriller', 'insiderthe'), ('Thriller', 'jurassicpark'), ('Thriller', 'kingkong'), ('Thriller', 'lawabidingcitizen'), ('Thriller', 'leviathan'), ('Thriller', 'lincolnlawyerthe'), ('Thriller', 'manchuriancandidatethe'), ('Thriller', 'manwhoknewtoomuchthe'), ('Thriller', 'margincall'), ('Thriller', 'mechanicthe'), ('Thriller', 'mimic'), ('Thriller', 'mirrors'), ('Thriller', 'missionimpossible'), ('Thriller', 'missionimpossibleii'), ('Thriller', 'moon'), ('Thriller', 'naturalbornkillers'), ('Thriller', 'nextthreedaysthe'), ('Thriller', 'ninesthe'), ('Thriller', 'ninjaassassin'), ('Thriller', 'nursebetty'), ('Thriller', 'oceanseleven'), ('Thriller', 'outofsight'), ('Thriller', 'peepingtom'), ('Thriller', 'pulpfiction'), ('Thriller', 'relicthe'), ('Thriller', 'reservoirdogs'), ('Thriller', 'ringu'), ('Thriller', 'se7en'), ('Thriller', 'sherlockholmes'), ('Thriller', 'sixthsensethe'), ('Thriller', 'strangersonatrain'), ('Thriller', 'swordfish'), ('Thriller', 'syriana'), ('Thriller', 'talentedmrripleythe'), ('Thriller', 'theragecarrie2'), ('Thriller', 'thingthe'), ('Thriller', 'timberfalls'), ('Thriller', 'tinkertailorsoldierspy'), ('Thriller', 'traffic'), ('Thriller', 'truelies'), ('Thriller', 'twinpeaks'), ('Thriller', 'unknown'), ('Thriller', 'usualsuspectsthe'), ('Thriller', 'uturn'), ('Thriller', 'valkyrie'), ('Thriller', 'virtuosity'), ('Thriller', 'whileshewasout'), ('Thriller', 'whistleblowerthe'), ('Thriller', 'whitejazz'), ('Thriller', 'wildthingsdiamondsintherough'), ('Thriller', 'windchill'), ('Thriller', 'xfilesfightthefuturethe')]

# %%
print not_working
# Out:
# []

# %%
print not_working
# Out:
# [('Short', 'mymotherdreamsthesatansdisciplesinnewyork')]

# %%
print not_working
# Out:
# [('Sci-Fi', '12monkeys'), ('Sci-Fi', '2001aspaceodyssey'), ('Sci-Fi', 'adjustmentbureauthe'), ('Sci-Fi', 'blade'), ('Sci-Fi', 'bookofelithe'), ('Sci-Fi', 'boxthe'), ('Sci-Fi', 'brazil'), ('Sci-Fi', 'cowboysaliens'), ('Sci-Fi', 'gamer'), ('Sci-Fi', 'gattaca'), ('Sci-Fi', 'godzilla'), ('Sci-Fi', 'hitchhikersguidetothegalaxythe'), ('Sci-Fi', 'iamnumberfour'), ('Sci-Fi', 'jurassicpark'), ('Sci-Fi', 'leviathan'), ('Sci-Fi', 'manchuriancandidatethe'), ('Sci-Fi', 'meninblack3'), ('Sci-Fi', 'mimic'), ('Sci-Fi', 'moon'), ('Sci-Fi', 'oblivion'), ('Sci-Fi', 'pandorum'), ('Sci-Fi', 'paul'), ('Sci-Fi', 'planetoftheapesthe'), ('Sci-Fi', 'postmanthe'), ('Sci-Fi', 'priest'), ('Sci-Fi', 'starshiptroopers'), ('Sci-Fi', 'startrek'), ('Sci-Fi', 'startrekfirstcontact'), ('Sci-Fi', 'startrekgenerations'), ('Sci-Fi', 'startrekiithewrathofkhan'), ('Sci-Fi', 'startrekthemotionpicture'), ('Sci-Fi', 'theragecarrie2'), ('Sci-Fi', 'thingthe'), ('Sci-Fi', 'timemachinethe'), ('Sci-Fi', 'tremors'), ('Sci-Fi', 'tron'), ('Sci-Fi', 'twins'), ('Sci-Fi', 'virtuosity'), ('Sci-Fi', 'wildwildwest'), ('Sci-Fi', 'xfilesfightthefuturethe'), ('Sci-Fi', 'xmen')]

# %%
print not_working
# Out:
# [('Romance', '10thingsihateaboutyou'), ('Romance', 'adjustmentbureauthe'), ('Romance', 'americanwerewolfinlondon'), ('Romance', 'artistthe'), ('Romance', 'blastfromthepastthe'), ('Romance', 'brothersbloomthe'), ('Romance', 'brucealmighty'), ('Romance', 'bulldurham'), ('Romance', 'crazystupidlove'), ('Romance', 'crouchingtigerhiddendragon'), ('Romance', 'cruelintentions'), ('Romance', 'curiouscaseofbenjaminbuttonthe'), ('Romance', 'extract'), ('Romance', 'familymanthe'), ('Romance', 'gardenstate'), ('Romance', 'hallpass'), ('Romance', 'hardtokill'), ('Romance', 'howtolosefriendsalienatepeople'), ('Romance', 'iloveyouphillipmorris'), ('Romance', 'inventingtheabbotts'), ('Romance', 'itscomplicated'), ('Romance', 'janeeyre'), ('Romance', 'lastofthemohicansthe'), ('Romance', 'loveandbasketball'), ('Romance', 'majesticthethebijou'), ('Romance', 'mantrouble'), ('Romance', 'midnightinparis'), ('Romance', 'montecarlo'), ('Romance', 'naturalbornkillers'), ('Romance', 'nextthreedaysthe'), ('Romance', 'ninotchka'), ('Romance', 'nostringsattached'), ('Romance', 'otherboleyngirlthe'), ('Romance', 'outofsight'), ('Romance', 'perksofbeingawallflowerthe'), ('Romance', 'prettywoman'), ('Romance', 'prideandprejudice'), ('Romance', 'rachelgettingmarried'), ('Romance', 'rustandbone'), ('Romance', 'savethelastdance'), ('Romance', 'sessionsthe'), ('Romance', 'sexandthecity'), ('Romance', 'slumdogmillionaire'), ('Romance', 'spanglish'), ('Romance', 'stelmosfire'), ('Romance', 'tamaradrewe'), ('Romance', 'theressomethingaboutmary'), ('Romance', 'threemusketeersthe'), ('Romance', 'tincup'), ('Romance', 'truelies'), ('Romance', 'uglytruththe'), ('Romance', 'whitechristmas')]

# %%
print not_working
# Out:
# [('Mystery', 'agnesofgod'), ('Mystery', 'aprilfoolsday'), ('Mystery', 'bourneultimatumthe'), ('Mystery', 'boxthe'), ('Mystery', 'brick'), ('Mystery', 'curiouscaseofbenjaminbuttonthe'), ('Mystery', 'devilinabluedress'), ('Mystery', 'easternpromises'), ('Mystery', 'fridaythe13th'), ('Mystery', 'gamethe'), ('Mystery', 'girlwiththedragontattoothe'), ('Mystery', 'hellraiserdeader'), ('Mystery', 'imaginariumofdoctorparnassusthe'), ('Mystery', 'kingkong'), ('Mystery', 'manchuriancandidatethe'), ('Mystery', 'mirrors'), ('Mystery', 'missionimpossibleii'), ('Mystery', 'moon'), ('Mystery', 'nightmareonelmstreeta'), ('Mystery', 'nightmareonelmstreetthefinalchapter'), ('Mystery', 'ninesthe'), ('Mystery', 'ringu'), ('Mystery', 'se7en'), ('Mystery', 'sherlockholmes'), ('Mystery', 'sixthsensethe'), ('Mystery', 'sleepyhollow'), ('Mystery', 'talentedmrripleythe'), ('Mystery', 'tinkertailorsoldierspy'), ('Mystery', 'twinpeaks'), ('Mystery', 'unknown'), ('Mystery', 'usualsuspectsthe'), ('Mystery', 'whitejazz'), ('Mystery', 'wildthingsdiamondsintherough')]

# %%
print not_working
# Out:
# [('Musical', 'marypoppins'), ('Musical', 'nashville'), ('Musical', 'newsies'), ('Musical', 'southpark'), ('Musical', 'sweeneytoddthedemonbarberoffleetstreet'), ('Musical', 'whitechristmas')]

# %%
print not_working
# Out:
# []

# %%
print not_working
# Out:
# [('Horror', 'aloneinthedark'), ('Horror', 'americanwerewolfinlondon'), ('Horror', 'aprilfoolsday'), ('Horror', 'blade'), ('Horror', 'bones'), ('Horror', 'constantine'), ('Horror', 'deeprising'), ('Horror', 'devilsadvocate'), ('Horror', 'freddyvsjason'), ('Horror', 'fridaythe13th'), ('Horror', 'fridaythe13thpartviiijasontakesmanhattan'), ('Horror', 'frightnight1985'), ('Horror', 'frightnight'), ('Horror', 'hellraiser'), ('Horror', 'hellraiserdeader'), ('Horror', 'hillshaveeyesthe'), ('Horror', 'jurassicpark'), ('Horror', 'leviathan'), ('Horror', 'littlenicky'), ('Horror', 'mimic'), ('Horror', 'mirrors'), ('Horror', 'nightmareonelmstreeta'), ('Horror', 'nightmareonelmstreetthefinalchapter'), ('Horror', 'ninesthe'), ('Horror', 'pandorum'), ('Horror', 'peepingtom'), ('Horror', 'petsemataryii'), ('Horror', 'priest'), ('Horror', 'queenofthedamned'), ('Horror', 'relicthe'), ('Horror', 'ringu'), ('Horror', 'silverbullet'), ('Horror', 'sixthsensethe'), ('Horror', 'sleepyhollow'), ('Horror', 'sweeneytoddthedemonbarberoffleetstreet'), ('Horror', 'talentedmrripleythe'), ('Horror', 'theragecarrie2'), ('Horror', 'thingthe'), ('Horror', 'timberfalls'), ('Horror', 'tremors'), ('Horror', 'twinpeaks'), ('Horror', 'windchill')]

# %%
print not_working
# Out:
# [('History', 'laststationthe'), ('History', 'lincoln'), ('History', 'otherboleyngirlthe')]

# %%
print not_working
# Out:
# [('Film-Noir', 'strangersonatrain'), ('Film-Noir', 'sunsetblvd')]

# %%
print not_working
# Out:
# [('Fantasy', 'antz'), ('Fantasy', 'beingjohnmalkovich'), ('Fantasy', 'brazil'), ('Fantasy', 'brucealmighty'), ('Fantasy', 'cirquedufreakthevampiresassistant'), ('Fantasy', 'clashofthetitans'), ('Fantasy', 'constantine'), ('Fantasy', 'crouchingtigerhiddendragon'), ('Fantasy', 'curiouscaseofbenjaminbuttonthe'), ('Fantasy', 'driveangry'), ('Fantasy', 'flintstonesthe'), ('Fantasy', 'freddyvsjason'), ('Fantasy', 'highlander'), ('Fantasy', 'imaginariumofdoctorparnassusthe'), ('Fantasy', 'littlenicky'), ('Fantasy', 'marypoppins'), ('Fantasy', 'midnightinparis'), ('Fantasy', 'thor'), ('Fantasy', 'tmnt'), ('Fantasy', 'tron')]

# %%
print not_working
# Out:
# [('Family', 'fantasticmrfox'), ('Family', 'flintstonesthe'), ('Family', 'marypoppins'), ('Family', 'mightymorphinpowerrangersthemovie'), ('Family', 'newsies'), ('Family', 'riseoftheguardians')]

# %%
print not_working
# Out:
# [('Adventure', '2001aspaceodyssey'), ('Adventure', 'antz'), ('Adventure', 'bookofelithe'), ('Adventure', 'bourneultimatumthe'), ('Adventure', 'brothersbloomthe'), ('Adventure', 'cirquedufreakthevampiresassistant'), ('Adventure', 'clashofthetitans'), ('Adventure', 'crouchingtigerhiddendragon'), ('Adventure', 'djangounchained'), ('Adventure', 'fantasticmrfox'), ('Adventure', 'hitchhikersguidetothegalaxythe'), ('Adventure', 'hudsonhawk'), ('Adventure', 'huntforredoctoberthe'), ('Adventure', 'imaginariumofdoctorparnassusthe'), ('Adventure', 'indianajonesandthetempleofdoom'), ('Adventure', 'jurassicpark'), ('Adventure', 'kingkong'), ('Adventure', 'lastofthemohicansthe'), ('Adventure', 'manwhoknewtoomuchthe'), ('Adventure', 'missionimpossible'), ('Adventure', 'missionimpossibleii'), ('Adventure', 'montecarlo'), ('Adventure', 'oblivion'), ('Adventure', 'paranorman'), ('Adventure', 'paul'), ('Adventure', 'postmanthe'), ('Adventure', 'riseoftheguardians'), ('Adventure', 'sherlockholmes'), ('Adventure', 'shrekthethird'), ('Adventure', 'startrek'), ('Adventure', 'startrekfirstcontact'), ('Adventure', 'startrekgenerations'), ('Adventure', 'startrekiithewrathofkhan'), ('Adventure', 'thor'), ('Adventure', 'threekings'), ('Adventure', 'threekingsspoilsofwar'), ('Adventure', 'threemusketeersthe'), ('Adventure', 'thunderbirds'), ('Adventure', 'timemachinethe'), ('Adventure', 'tmnt'), ('Adventure', 'tron'), ('Adventure', 'truelies')]

# %%
print not_working
# Out:
# [('Crime', 'absolutepower'), ('Crime', 'americangangster'), ('Crime', 'analyzethis'), ('Crime', 'badsanta'), ('Crime', 'bigwhitethe'), ('Crime', 'blingringthe'), ('Crime', 'bodyheat'), ('Crime', 'bottlerocket'), ('Crime', 'brothersbloomthe'), ('Crime', 'capote'), ('Crime', 'catchmeifyoucan'), ('Crime', 'cecilbdemented'), ('Crime', 'chaos'), ('Crime', 'crank'), ('Crime', 'devilinabluedress'), ('Crime', 'driveangry'), ('Crime', 'easternpromises'), ('Crime', 'extract'), ('Crime', 'frozenriver'), ('Crime', 'girlwiththedragontattoothe'), ('Crime', 'go'), ('Crime', 'gonein60seconds'), ('Crime', 'heat'), ('Crime', 'henryscrime'), ('Crime', 'horriblebosses'), ('Crime', 'hudsonhawk'), ('Crime', 'inthebedroom'), ('Crime', 'lawabidingcitizen'), ('Crime', 'lincolnlawyerthe'), ('Crime', 'meanstreets'), ('Crime', 'mechanicthe'), ('Crime', 'minisfirsttime'), ('Crime', 'naturalbornkillers'), ('Crime', 'nextthreedaysthe'), ('Crime', 'ninjaassassin'), ('Crime', 'oceanseleven'), ('Crime', 'outofsight'), ('Crime', 'perfectworlda'), ('Crime', 'pulpfiction'), ('Crime', 'reservoirdogs'), ('Crime', 'rocknrolla'), ('Crime', 'scarface'), ('Crime', 'sherlockholmes'), ('Crime', 'slumdogmillionaire'), ('Crime', 'talentedmrripleythe'), ('Crime', 'traffic'), ('Crime', 'usualsuspectsthe'), ('Crime', 'whileshewasout'), ('Crime', 'whitejazz'), ('Crime', 'wildthings'), ('Crime', 'wolfofwallstreetthe')]

# %%
avatar = parse_movie(movie1, 'Adventure', 'avatar') 
print avatar.head()
# Out:
#                             RawLine   Title      Genre    Char  LineID  \
# 0                            AVATAR  avatar  Adventure  AVATAR       1
# 1                        Written by  avatar  Adventure  AVATAR       1
# 2                     James Cameron  avatar  Adventure  AVATAR       1
# 3                      VOICE (V.O.)  avatar  Adventure   VOICE       2
# 4  When I was lying there in the VA  avatar  Adventure   VOICE       2
#
#                              Speech
# 0
# 1                        Written by
# 2                     James Cameron
# 3
# 4  When I was lying there in the VA

# %%
movie1 = pd.read_fwf('./data/imsdb_scenes_dialogs_nov_2015/dialogs/Adventure/avatar_dialog.txt',
                    header=None, names=["RawLine"],encoding='utf')
print movie1
# Out:
#                                         RawLine
# 0                                        AVATAR
# 1                                    Written by
# 2                                 James Cameron
# 3                                  VOICE (V.O.)
# 4              When I was lying there in the VA
# 5       hospital, with a big hole blown through
# 6       the middle of my life, I started having
# 7                       these dreams of flying.
# 8                                  VOICE (V.O.)
# 9       Sooner or later though, you always have
# 10                                to wake up...
# 11                                      CUT TO:
# 12                                  JAKE (V.O.)
# 13     They can fix a spinal, if you've got the
# 14       money. But not on vet benefits, not in
# 15                                this economy.
# 16                             PERKY NEWSCASTER
# 17         The Bengal tiger, extinct for over a
# 18         century, is making a comeback. These
# 19         cloned tiger cubs at the Beijing Zoo
# 20                                       are...
# 21                                           2.
# 22                                  JAKE (V.O.)
# 23       I became a Marine for the hardship. To
# 24     be hammered on the anvil of life. I told
# 25       myself I could pass any test a man can
# 26                                        pass.
# 27                                      CUT TO:
# 28                                  JAKE (V.O.)
# 29      Let's get it straight up front. I don't
# ...                                         ...
# 2675                              remembered --
# 2676                                    TSU'TEY
# 2677      -- I fought with Toruk Macto, we were
# 2678     brothers -- and he was my last shadow.
# 2679                                       JAKE
# 2680                                    (NA'VI)
# 2681      Forgive me, my Brother. Go now to the
# 2682                             Mother Spirit.
# 2683                               DISSOLVE TO:
# 2684                                JAKE (V.O.)
# 2685    A few chose to stay. Fewer were chosen.
# 2686                                    CUT TO:
# 2687                                       150.
# 2688                                    CUT TO:
# 2689                                JAKE (V.O.)
# 2690      The forest will heal, and so will the
# 2691   hearts of the People. New life keeps the
# 2692     energy flowing, like the breath of the
# 2693                                     world.
# 2694                                JAKE (V.O.)
# 2695                  This is my last videolog.
# 2696                                       JAKE
# 2697  The science guys will keep the lights on,
# 2698         here. But I won't miss this place.
# 2699                                JAKE (V.O.)
# 2700   I better wrap this up. There's a funeral
# 2701   tonight, and I don't want to be late. It
# 2702              was someone very close to me.
# 2703                                       151.
# 2704                               CUT TO BLACK
#
# [2705 rows x 1 columns]

# %%
### create a csv combiner code
# !sed 1d Output*.csv > merged.csv

# %%
# !sed 1d OutputAdventureCharacters.csv >> merged.csv

# %%
# !sed 1d OutputCrimeCharacters.csv >> merged.csv

# %%
# !sed 1d OutputDramaCharacters.csv >> merged.csv

# %%
### this will take the merged csv's and make a random sample from them
### share random_sampling.csv to google drive and give mathaholic@berkeley.edu, michelle.m.kim@berkeley.edu
### and icwang@ischool.berkeley.edu write privledges
m = pd.read_csv('merged.csv', sep = ',', names=['char', 'genre', 'title', 'line_count'])
m['pkey'] = m['char'].map(lambda x: x.lower()).map(lambda x: x.replace(' ', '_')) + '-' + m['title'].map(lambda x: x.lower())
m_sample = m.sample(frac=0.10, random_state=1701)
m_sample.to_csv('random_sampling.csv', sep = ',', index=False)

# %%
m.head()
# Out:
#          char   genre    title line_count
# 0      LERNER  Action  platoon         69
# 1       ELIAS  Action  platoon        229
# 2    CRAWFORD  Action  platoon         32
# 3  BIG HAROLD  Action  platoon         55
# 4        KING  Action  platoon        184

# %%
m['genre'].value_counts()
# Out:
# Drama        6433
# Thriller     3677
# Action       2729
# Crime        2271
# Romance      1932
# Adventure    1385
# Sci-Fi       1244
# Horror       1209
# Mystery      1073
# Fantasy      1015
# Family        340
# War           308
# Animation     280
# Musical       211
# Western       142
# Music          87
# Film-Noir      31
# Genre          14
# Sport           6
# Name: genre, dtype: int64

# %%
m['pkey'] = m['char'].map(lambda x: x.lower()).map(lambda x: x.replace(' ', '_')) + '-' + m['title'].map(lambda x: x.lower())

# %%
m.head()
# Out:
#          char   genre    title line_count                pkey
# 0      LERNER  Action  platoon         69      lerner-platoon
# 1       ELIAS  Action  platoon        229       elias-platoon
# 2    CRAWFORD  Action  platoon         32    crawford-platoon
# 3  BIG HAROLD  Action  platoon         55  big_harold-platoon
# 4        KING  Action  platoon        184        king-platoon

# %%
m_sample = m.sample(frac=0.10, random_state=1701)
m_sample.to_csv('random_sampling.csv', sep = ',', index=False)

# %%
m_sample.shape
# Out:
# (2439, 5)
